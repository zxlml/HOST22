# %% [markdown]
# # 重复100次实验  取平均值

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.utils import shuffle
from imblearn.over_sampling import SMOTE                # 过抽样处理库SMOTE
from imblearn.under_sampling import RandomUnderSampler  # 欠抽样处理库RandomUnderSample
from imblearn.over_sampling import BorderlineSMOTE
from imblearn.combine import SMOTEENN, SMOTETomek
from sklearn.ensemble import RandomForestClassifier
from sklearn.decomposition import PCA           #加载PCA算法包
from sklearn.metrics import mean_squared_error as mse
import time
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
data_names = ['data.xlsx','AES_T400.xlsx','AES_T700.xlsx','AES_T800.xlsx','AES_T900.xlsx',
                  'AES_T1200.xlsx','AES_T1300.xlsx','AES_T1400.xlsx','AES_T2000.xlsx',]

def create_numerics(data):
    # Get nominal columns
    nominal_cols = data.select_dtypes(include='object').columns.tolist()

    # Turn nominal to numeric
    for nom in nominal_cols:
        enc = LabelEncoder()
        enc.fit(data[nom])
        data[nom] = enc.transform(data[nom])
    return data
    
def prepare_data(case = 0 , feature_choice = 0, data_id = 0, ispca = 0):

    data = pd.read_excel(data_names[data_id])
    data = data.dropna()

    data = create_numerics(data)
    data = shuffle(data)
    
    data = data.values
    y = data[:,-1]
    x = data[:,0:-1]
    if(ispca == 1):
        pca = PCA(n_components=0.9)
        pca.fit(x)
        x = pca.transform(x)
    
    if(feature_choice == 1):    #我们的  先验知识
        l=[0,4,8,12]
        x = data[:,l]
    elif(feature_choice == 2):  # 非均衡下 SHAP的结果  和   任何情况下 PI 的结果
        l=[0,1,3,4,8,12]  
        x = data[:,l]    
    elif(feature_choice == 3):  # 均衡下  SHAP 的结果  
        l=[0,4,8,10,12,15]
        x = data[:,l]    
        
    if(data_id == 0):    
        print("Original samples:",len(y))
        if(case ==1):
            model_smote = SMOTE(random_state=42)                      # 建立SMOTE模型对象
            x, y = model_smote.fit_sample(x, y)         # 输入数据做过抽样处理
        elif(case ==2):
            model_RandomUnderSample = RandomUnderSampler(random_state=42)   # 建立RandomUnderSampler模型对象
            x, y = model_RandomUnderSample.fit_sample(x, y)   # 输入数据做欠抽样处理
        elif(case ==3):
            oversample = BorderlineSMOTE(random_state=42)
            x, y = oversample.fit_resample(x, y)
        elif(case ==4):
            smt = SMOTETomek(random_state=42)
            x,y =  smt.fit_sample(x, y)
        elif(case ==5):
            smt = SMOTEENN(random_state=42)
            x,y =  smt.fit_sample(x, y)    
        print("New samples:",len(y))
        print(y.sum())
    scaler = MinMaxScaler(feature_range=(0, 1))
    x = scaler.fit_transform(x)
    return(x,y)
#     x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=ratio, random_state=1)
#     return(x_train, x_test, y_train, y_test)

# %%
def RF_test(rf,x_test, y_test):
    
    start = time.time()
    y_pred = rf.predict(x_test)
    end = time.time()
    
    time_    = 1000*(end - start)  # ms
    accuracy = 100 * accuracy_score(y_test, y_pred)
    f1score  = 100 * f1_score(y_test, y_pred, average='macro')
    
    total_test   = len(y_test)
    tp = 0
    tn = 0
    fp = 0
    fn = 0
    for i in range(total_test):
        if(y_test[i] == y_pred[i]   and y_pred[i]==1): #trojan
            tp += 1
        elif(y_test[i] == y_pred[i] and y_pred[i]==0): #normal
            tn += 1
        elif(y_test[i] != y_pred[i] and y_pred[i]==1): #normal
            fp += 1
        elif(y_test[i] != y_pred[i] and y_pred[i]==0): #normal
            fn += 1
    
    tpr         = tp/(tp+fn)
    tnr         = tn/(tn+fp)
    precision   = tp/(tp+fp)
    
    print("在数据集"+str(data_names[id_data]+"上的测试结果"))
    print("TIME：",time_)
    print("TPR ：",tpr)
    print("TNR ：",tnr)
    print("ACC ：",accuracy)
    print("PRE ：",precision)
    print("F1  ：" ,f1score)
    return time_,tpr,tnr,accuracy,precision,f1score

# %%
def one_exp(rf, sampling, id_data, id_features, is_pca):

    # 测试集  不扩充， 但是要选维度   选 数据集编号 
    x_test, y_test = prepare_data(case = 0 , feature_choice = id_features, data_id = id_data, ispca = is_pca)
    time_,tpr,tnr,accuracy,precision,f1score = RF_test(rf,x_test, y_test)
    return time_,tpr,tnr,accuracy,precision,f1score

# %% [markdown]
# # 重复实验

# %%
# sampling cases: 0不处理    1 过采样Smote  2 随机欠采样      3 Borderline Smote  4 Smote+Toek 5 SmoteEEN

# 特征选择      ：0： 全选   1： 1 4 8 12   2：1 2 4 5 9 13   3：1 4 5 9 13 16

# 数据选择 data_names = ['data.xlsx','AES_T400.xlsx','AES_T700.xlsx','AES_T800.xlsx','AES_T900.xlsx',
# 'AES_T1200.xlsx','AES_T1300.xlsx','AES_T1400.xlsx','AES_T2000.xlsx',]
# 0 是训练集  其他 1-8 是测试集

# PCA处理       ：0 则不PCA  1  则PCA


if __name__ == '__main__':
    sampling = 5     # 过采样技术  建议 5
    id_features = 1  # 降维技术    建议 2
    is_pca = 0       # 是否PCA     建议 0 
    p1=[];p2=[];p3=[];p4=[];p5=[];p6=[];p7=[];p8=[];
    
    for i in range(0,50):
        x_train, y_train = prepare_data(case = sampling , feature_choice = id_features, data_id = 0, ispca = is_pca)
        rf = RandomForestClassifier(n_estimators=5, max_depth=5, random_state=1)
        rf.fit(x_train, y_train)   
        id_data = 1
        p1.append(one_exp(rf, sampling, id_data, id_features, is_pca))
        id_data = 2
        p2.append(one_exp(rf, sampling, id_data, id_features, is_pca))
        id_data = 3
        p3.append(one_exp(rf, sampling, id_data, id_features, is_pca))
        id_data = 4
        p4.append(one_exp(rf, sampling, id_data, id_features, is_pca))
        id_data = 5
        p5.append(one_exp(rf, sampling, id_data, id_features, is_pca))
        id_data = 6
        p6.append(one_exp(rf, sampling, id_data, id_features, is_pca))
        id_data = 7
        p7.append(one_exp(rf, sampling, id_data, id_features, is_pca))
        id_data = 8
        p8.append(one_exp(rf, sampling, id_data, id_features, is_pca))
# Out:
# Original samples: 6915
# New samples: 11920
# 5936
# 在数据集AES_T400.xlsx上的测试结果
# TIME： 1.9974708557128906
# TPR ： 0.9871794871794872
# TNR ： 1.0
# ACC ： 99.98507685420086
# PRE ： 1.0
# F1  ： 99.67364491534298
# 在数据集AES_T700.xlsx上的测试结果
# TIME： 0.9975433349609375
# TPR ： 0.9814814814814815
# TNR ： 1.0
# ACC ： 99.98502321401827
# PRE ： 1.0
# F1  ： 99.52893584087809
# 在数据集AES_T800.xlsx上的测试结果
# TIME： 1.9946098327636719
# TPR ： 0.9940119760479041
# TNR ： 1.0
# ACC ： 99.98540997957397
# PRE ： 1.0
# F1  ： 99.84611153209283
# 在数据集AES_T900.xlsx上的测试结果
# TIME： 1.995086669921875
# TPR ： 0.9978354978354979
# TNR ： 1.0
# ACC ： 99.98601202965449
# PRE ： 1.0
# F1  ： 99.94209050131124
# 在数据集AES_T1200.xlsx上的测试结果
# TIME： 1.9881725311279297
# TPR ： 0.9978354978354979
# TNR ： 1.0
# ACC ： 99.98601202965449
# PRE ： 1.0
# F1  ： 99.94209050131124
# 在数据集AES_T1300.xlsx上的测试结果
# TIME： 1.9917488098144531
# TPR ： 0.9814814814814815
# TNR ： 1.0
# ACC ： 99.98712169993561
# PRE ： 1.0
# F1  ： 99.52946836894286
# 在数据集AES_T1400.xlsx上的测试结果
# TIME： 2.022981643676758
# TPR ： 0.9939393939393939
# TNR ： 1.0
# ACC ： 99.9918005903575
# PRE ： 1.0
# F1  ： 99.8459464372082
# 在数据集AES_T2000.xlsx上的测试结果
# TIME： 1.9943714141845703
# TPR ： 0.9939393939393939
# TNR ： 1.0
# ACC ： 99.98540572095739
# PRE ： 1.0
# F1  ： 99.84428599835242
# Original samples: 6915
# New samples: 11923
# 5939
# 在数据集AES_T400.xlsx上的测试结果
# TIME： 0.9970664978027344
# TPR ： 0.9871794871794872
# TNR ： 1.0
# ACC ： 99.98507685420086
# PRE ： 1.0
# F1  ： 99.67364491534298
# 在数据集AES_T700.xlsx上的测试结果
# TIME： 1.9946098327636719
# TPR ： 0.9814814814814815
# TNR ： 1.0
# ACC ： 99.98502321401827
# PRE ： 1.0
# F1  ： 99.52893584087809
# 在数据集AES_T800.xlsx上的测试结果
# TIME： 1.9946098327636719
# TPR ： 0.9940119760479041
# TNR ： 1.0
# ACC ： 99.98540997957397
# PRE ： 1.0
# F1  ： 99.84611153209283
# 在数据集AES_T900.xlsx上的测试结果
# TIME： 0.9963512420654297
# TPR ： 0.9978354978354979
# TNR ： 1.0
# ACC ： 99.98601202965449
# PRE ： 1.0
# F1  ： 99.94209050131124
# 在数据集AES_T1200.xlsx上的测试结果
# TIME： 1.9974708557128906
# TPR ： 0.9978354978354979
# TNR ： 1.0
# ACC ： 99.98601202965449
# PRE ： 1.0
# F1  ： 99.94209050131124
# 在数据集AES_T1300.xlsx上的测试结果
# TIME： 1.9922256469726562
# TPR ： 0.9814814814814815
# TNR ： 1.0
# ACC ： 99.98712169993561
# PRE ： 1.0
# F1  ： 99.52946836894286
# 在数据集AES_T1400.xlsx上的测试结果
# TIME： 3.0210018157958984
# TPR ： 0.9939393939393939
# TNR ： 1.0
# ACC ： 99.9918005903575
# PRE ： 1.0
# F1  ： 99.8459464372082
# 在数据集AES_T2000.xlsx上的测试结果
# TIME： 1.9941329956054688
# TPR ： 0.9939393939393939
# TNR ： 1.0
# ACC ： 99.98540572095739
# PRE ： 1.0
# F1  ： 99.84428599835242
# Original samples: 6915
# New samples: 11917
# 5933
# 在数据集AES_T400.xlsx上的测试结果
# TIME： 0.9970664978027344
# TPR ： 0.9871794871794872
# TNR ： 1.0
# ACC ： 99.98507685420086
# PRE ： 1.0
# F1  ： 99.67364491534298
# 在数据集AES_T700.xlsx上的测试结果
# TIME： 0.9975433349609375
# TPR ： 0.9814814814814815
# TNR ： 1.0
# ACC ： 99.98502321401827
# PRE ： 1.0
# F1  ： 99.52893584087809
# 在数据集AES_T800.xlsx上的测试结果
# TIME： 1.9946098327636719
# TPR ： 0.9940119760479041
# TNR ： 1.0
# ACC ： 99.98540997957397
# PRE ： 1.0
# F1  ： 99.84611153209283
# 在数据集AES_T900.xlsx上的测试结果
# TIME： 0.9663105010986328
# TPR ： 0.9978354978354979
# TNR ： 1.0
# ACC ： 99.98601202965449
# PRE ： 1.0
# F1  ： 99.94209050131124
# 在数据集AES_T1200.xlsx上的测试结果
# TIME： 3.020048141479492
# TPR ： 0.9978354978354979
# TNR ： 1.0
# ACC ： 99.98601202965449
# PRE ： 1.0
# F1  ： 99.94209050131124
# 在数据集AES_T1300.xlsx上的测试结果
# TIME： 0.9970664978027344
# TPR ： 0.9814814814814815
# TNR ： 1.0
# ACC ： 99.98712169993561
# PRE ： 1.0
# F1  ： 99.52946836894286
# 在数据集AES_T1400.xlsx上的测试结果
# TIME： 2.991199493408203
# TPR ： 0.9939393939393939
# TNR ： 1.0
# ACC ： 99.9918005903575
# PRE ： 1.0
# F1  ： 99.8459464372082
# 在数据集AES_T2000.xlsx上的测试结果
# TIME： 1.9953250885009766
# TPR ： 0.9939393939393939
# TNR ： 1.0
# ACC ： 99.98540572095739
# PRE ： 1.0
# F1  ： 99.84428599835242
# Original samples: 6915
# New samples: 11912
# 5928
# 在数据集AES_T400.xlsx上的测试结果
# TIME： 1.9657611846923828
# TPR ： 0.9871794871794872
# TNR ： 1.0
# ACC ： 99.98507685420086
# PRE ： 1.0
# F1  ： 99.67364491534298
# 在数据集AES_T700.xlsx上的测试结果
# TIME： 1.9943714141845703
# TPR ： 0.9814814814814815
# TNR ： 1.0
# ACC ： 99.98502321401827
# PRE ： 1.0
# F1  ： 99.52893584087809
# 在数据集AES_T800.xlsx上的测试结果
# TIME： 1.9943714141845703
# TPR ： 0.9940119760479041
# TNR ： 1.0
# ACC ： 99.98540997957397
# PRE ： 1.0
# F1  ： 99.84611153209283
# 在数据集AES_T900.xlsx上的测试结果
# TIME： 0.9970664978027344
# TPR ： 0.9978354978354979
# TNR ： 1.0
# ACC ： 99.98601202965449
# PRE ： 1.0
# F1  ： 99.94209050131124
# 在数据集AES_T1200.xlsx上的测试结果
# TIME： 1.9946098327636719
# TPR ： 0.9978354978354979
# TNR ： 1.0
# ACC ： 99.98601202965449
# PRE ： 1.0
# F1  ： 99.94209050131124
# 在数据集AES_T1300.xlsx上的测试结果
# TIME： 0.9970664978027344
# TPR ： 0.9814814814814815
# TNR ： 1.0
# ACC ： 99.98712169993561
# PRE ： 1.0
# F1  ： 99.52946836894286
# 在数据集AES_T1400.xlsx上的测试结果
# TIME： 2.9931068420410156
# TPR ： 0.9939393939393939
# TNR ： 1.0
# ACC ： 99.9918005903575
# PRE ： 1.0
# F1  ： 99.8459464372082
# 在数据集AES_T2000.xlsx上的测试结果
# TIME： 1.9664764404296875
# TPR ： 0.9939393939393939
# TNR ： 1.0
# ACC ： 99.98540572095739
# PRE ： 1.0
# F1  ： 99.84428599835242
# Original samples: 6915
# New samples: 11919
# 5935
# 在数据集AES_T400.xlsx上的测试结果
# TIME： 0.9970664978027344
# TPR ： 0.9871794871794872
# TNR ： 1.0
# ACC ： 99.98507685420086
# PRE ： 1.0
# F1  ： 99.67364491534298
# 在数据集AES_T700.xlsx上的测试结果
# TIME： 1.9948482513427734
# TPR ： 0.9814814814814815
# TNR ： 1.0
# ACC ： 99.98502321401827
# PRE ： 1.0
# F1  ： 99.52893584087809
# 在数据集AES_T800.xlsx上的测试结果
# TIME： 1.9948482513427734
# TPR ： 0.9940119760479041
# TNR ： 1.0
# ACC ： 99.98540997957397
# PRE ： 1.0
# F1  ： 99.84611153209283
# 在数据集AES_T900.xlsx上的测试结果
# TIME： 1.9946098327636719
# TPR ： 0.9978354978354979
# TNR ： 1.0
# ACC ： 99.98601202965449
# PRE ： 1.0
# F1  ： 99.94209050131124
# 在数据集AES_T1200.xlsx上的测试结果
# TIME： 1.9948482513427734
# TPR ： 0.9978354978354979
# TNR ： 1.0
# ACC ： 99.98601202965449
# PRE ： 1.0
# F1  ： 99.94209050131124
# 在数据集AES_T1300.xlsx上的测试结果
# TIME： 1.9946098327636719
# TPR ： 0.9814814814814815
# TNR ： 1.0
# ACC ： 99.98712169993561
# PRE ： 1.0
# F1  ： 99.52946836894286
# 在数据集AES_T1400.xlsx上的测试结果
# TIME： 2.991914749145508
# TPR ： 0.9939393939393939
# TNR ： 1.0
# ACC ： 99.9918005903575
# PRE ： 1.0
# F1  ： 99.8459464372082
# 在数据集AES_T2000.xlsx上的测试结果
# TIME： 1.9953250885009766
# TPR ： 0.9939393939393939
# TNR ： 1.0
# ACC ： 99.98540572095739
# PRE ： 1.0
# F1  ： 99.84428599835242
# Original samples: 6915
# New samples: 11909
# 5925
# 在数据集AES_T400.xlsx上的测试结果
# TIME： 1.9946098327636719
# TPR ： 0.9871794871794872
# TNR ： 1.0
# ACC ： 99.98507685420086
# PRE ： 1.0
# F1  ： 99.67364491534298
# 在数据集AES_T700.xlsx上的测试结果
# TIME： 1.9946098327636719
# TPR ： 0.9814814814814815
# TNR ： 1.0
# ACC ： 99.98502321401827
# PRE ： 1.0
# F1  ： 99.52893584087809
# 在数据集AES_T800.xlsx上的测试结果
# TIME： 1.9943714141845703
# TPR ： 0.9940119760479041
# TNR ： 1.0
# ACC ： 99.98540997957397
# PRE ： 1.0
# F1  ： 99.84611153209283
# 在数据集AES_T900.xlsx上的测试结果
# TIME： 1.9674301147460938
# TPR ： 0.9978354978354979
# TNR ： 1.0
# ACC ： 99.98601202965449
# PRE ： 1.0
# F1  ： 99.94209050131124
# 在数据集AES_T1200.xlsx上的测试结果
# TIME： 1.9946098327636719
# TPR ： 0.9978354978354979
# TNR ： 1.0
# ACC ： 99.98601202965449
# PRE ： 1.0
# F1  ： 99.94209050131124
# 在数据集AES_T1300.xlsx上的测试结果
# TIME： 1.9946098327636719
# TPR ： 0.9814814814814815
# TNR ： 1.0
# ACC ： 99.98712169993561
# PRE ： 1.0
# F1  ： 99.52946836894286
# 在数据集AES_T1400.xlsx上的测试结果
# TIME： 2.992391586303711
# TPR ： 0.9939393939393939
# TNR ： 1.0
# ACC ： 99.9918005903575
# PRE ： 1.0
# F1  ： 99.8459464372082
# 在数据集AES_T2000.xlsx上的测试结果
# TIME： 1.9943714141845703
# TPR ： 0.9939393939393939
# TNR ： 1.0
# ACC ： 99.98540572095739
# PRE ： 1.0
# F1  ： 99.84428599835242
# Original samples: 6915
# New samples: 11922
# 5938
# 在数据集AES_T400.xlsx上的测试结果
# TIME： 1.9943714141845703
# TPR ： 0.9871794871794872
# TNR ： 1.0
# ACC ： 99.98507685420086
# PRE ： 1.0
# F1  ： 99.67364491534298
# 在数据集AES_T700.xlsx上的测试结果
# TIME： 1.9948482513427734
# TPR ： 0.9814814814814815
# TNR ： 1.0
# ACC ： 99.98502321401827
# PRE ： 1.0
# F1  ： 99.52893584087809
# 在数据集AES_T800.xlsx上的测试结果
# TIME： 1.9974708557128906
# TPR ： 0.9940119760479041
# TNR ： 1.0
# ACC ： 99.98540997957397
# PRE ： 1.0
# F1  ： 99.84611153209283
# 在数据集AES_T900.xlsx上的测试结果
# TIME： 1.9946098327636719
# TPR ： 0.9978354978354979
# TNR ： 1.0
# ACC ： 99.98601202965449
# PRE ： 1.0
# F1  ： 99.94209050131124
# 在数据集AES_T1200.xlsx上的测试结果
# TIME： 1.997232437133789
# TPR ： 0.9978354978354979
# TNR ： 1.0
# ACC ： 99.98601202965449
# PRE ： 1.0
# F1  ： 99.94209050131124
# 在数据集AES_T1300.xlsx上的测试结果
# TIME： 1.9955635070800781
# TPR ： 0.9814814814814815
# TNR ： 1.0
# ACC ： 99.98712169993561
# PRE ： 1.0
# F1  ： 99.52946836894286
# 在数据集AES_T1400.xlsx上的测试结果
# TIME： 2.964019775390625
# TPR ： 0.9939393939393939
# TNR ： 1.0
# ACC ： 99.9918005903575
# PRE ： 1.0
# F1  ： 99.8459464372082
# 在数据集AES_T2000.xlsx上的测试结果
# TIME： 0.9977817535400391
# TPR ： 0.9939393939393939
# TNR ： 1.0
# ACC ： 99.98540572095739
# PRE ： 1.0
# F1  ： 99.84428599835242
# Original samples: 6915
# New samples: 11918
# 5934
# 在数据集AES_T400.xlsx上的测试结果
# TIME： 1.9943714141845703
# TPR ： 0.9871794871794872
# TNR ： 1.0
# ACC ： 99.98507685420086
# PRE ： 1.0
# F1  ： 99.67364491534298
# 在数据集AES_T700.xlsx上的测试结果
# TIME： 1.9946098327636719
# TPR ： 0.9814814814814815
# TNR ： 1.0
# ACC ： 99.98502321401827
# PRE ： 1.0
# F1  ： 99.52893584087809
# 在数据集AES_T800.xlsx上的测试结果
# TIME： 1.9915103912353516
# TPR ： 0.9940119760479041
# TNR ： 1.0
# ACC ： 99.98540997957397
# PRE ： 1.0
# F1  ： 99.84611153209283
# 在数据集AES_T900.xlsx上的测试结果
# TIME： 1.9946098327636719
# TPR ： 0.9978354978354979
# TNR ： 1.0
# ACC ： 99.98601202965449
# PRE ： 1.0
# F1  ： 99.94209050131124
# 在数据集AES_T1200.xlsx上的测试结果
# TIME： 1.9664764404296875
# TPR ： 0.9978354978354979
# TNR ： 1.0
# ACC ： 99.98601202965449
# PRE ： 1.0
# F1  ： 99.94209050131124
# 在数据集AES_T1300.xlsx上的测试结果
# TIME： 1.9946098327636719
# TPR ： 0.9814814814814815
# TNR ： 1.0
# ACC ： 99.98712169993561
# PRE ： 1.0
# F1  ： 99.52946836894286
# 在数据集AES_T1400.xlsx上的测试结果
# TIME： 2.9921531677246094
# TPR ： 0.9939393939393939
# TNR ： 1.0
# ACC ： 99.9918005903575
# PRE ： 1.0
# F1  ： 99.8459464372082
# 在数据集AES_T2000.xlsx上的测试结果
# TIME： 1.9907951354980469
# TPR ： 0.9939393939393939
# TNR ： 1.0
# ACC ： 99.98540572095739
# PRE ： 1.0
# F1  ： 99.84428599835242
# Original samples: 6915
# New samples: 11916
# 5932
# 在数据集AES_T400.xlsx上的测试结果
# TIME： 1.9943714141845703
# TPR ： 0.9871794871794872
# TNR ： 1.0
# ACC ： 99.98507685420086
# PRE ： 1.0
# F1  ： 99.67364491534298
# 在数据集AES_T700.xlsx上的测试结果
# TIME： 0.9973049163818359
# TPR ： 0.9814814814814815
# TNR ： 1.0
# ACC ： 99.98502321401827
# PRE ： 1.0
# F1  ： 99.52893584087809
# 在数据集AES_T800.xlsx上的测试结果
# TIME： 1.9948482513427734
# TPR ： 0.9940119760479041
# TNR ： 1.0
# ACC ： 99.98540997957397
# PRE ： 1.0
# F1  ： 99.84611153209283
# 在数据集AES_T900.xlsx上的测试结果
# TIME： 1.9907951354980469
# TPR ： 0.9978354978354979
# TNR ： 1.0
# ACC ： 99.98601202965449
# PRE ： 1.0
# F1  ： 99.94209050131124
# 在数据集AES_T1200.xlsx上的测试结果
# TIME： 1.995086669921875
# TPR ： 0.9978354978354979
# TNR ： 1.0
# ACC ： 99.98601202965449
# PRE ： 1.0
# F1  ： 99.94209050131124
# 在数据集AES_T1300.xlsx上的测试结果
# TIME： 1.9946098327636719
# TPR ： 0.9814814814814815
# TNR ： 1.0
# ACC ： 99.98712169993561
# PRE ： 1.0
# F1  ： 99.52946836894286
# 在数据集AES_T1400.xlsx上的测试结果
# TIME： 2.9914379119873047
# TPR ： 0.9939393939393939
# TNR ： 1.0
# ACC ： 99.9918005903575
# PRE ： 1.0
# F1  ： 99.8459464372082
# 在数据集AES_T2000.xlsx上的测试结果
# TIME： 1.9938945770263672
# TPR ： 0.9939393939393939
# TNR ： 1.0
# ACC ： 99.98540572095739
# PRE ： 1.0
# F1  ： 99.84428599835242
# Original samples: 6915
# New samples: 11924
# 5940
# 在数据集AES_T400.xlsx上的测试结果
# TIME： 0.9973049163818359
# TPR ： 0.9871794871794872
# TNR ： 1.0
# ACC ： 99.98507685420086
# PRE ： 1.0
# F1  ： 99.67364491534298
# 在数据集AES_T700.xlsx上的测试结果
# TIME： 1.9946098327636719
# TPR ： 0.9814814814814815
# TNR ： 1.0
# ACC ： 99.98502321401827
# PRE ： 1.0
# F1  ： 99.52893584087809
# 在数据集AES_T800.xlsx上的测试结果
# TIME： 1.9938945770263672
# TPR ： 0.9940119760479041
# TNR ： 1.0
# ACC ： 99.98540997957397
# PRE ： 1.0
# F1  ： 99.84611153209283
# 在数据集AES_T900.xlsx上的测试结果
# TIME： 1.9948482513427734
# TPR ： 0.9978354978354979
# TNR ： 1.0
# ACC ： 99.98601202965449
# PRE ： 1.0
# F1  ： 99.94209050131124
# 在数据集AES_T1200.xlsx上的测试结果
# TIME： 1.995086669921875
# TPR ： 0.9978354978354979
# TNR ： 1.0
# ACC ： 99.98601202965449
# PRE ： 1.0
# F1  ： 99.94209050131124
# 在数据集AES_T1300.xlsx上的测试结果
# TIME： 2.0227432250976562
# TPR ： 0.9814814814814815
# TNR ： 1.0
# ACC ： 99.98712169993561
# PRE ： 1.0
# F1  ： 99.52946836894286
# 在数据集AES_T1400.xlsx上的测试结果
# TIME： 2.992391586303711
# TPR ： 0.9939393939393939
# TNR ： 1.0
# ACC ： 99.9918005903575
# PRE ： 1.0
# F1  ： 99.8459464372082
# 在数据集AES_T2000.xlsx上的测试结果
# TIME： 1.9948482513427734
# TPR ： 0.9939393939393939
# TNR ： 1.0
# ACC ： 99.98540572095739
# PRE ： 1.0
# F1  ： 99.84428599835242
# Original samples: 6915
# New samples: 11896
# 5912
# 在数据集AES_T400.xlsx上的测试结果
# TIME： 1.995086669921875
# TPR ： 0.9871794871794872
# TNR ： 1.0
# ACC ： 99.98507685420086
# PRE ： 1.0
# F1  ： 99.67364491534298
# 在数据集AES_T700.xlsx上的测试结果
# TIME： 0.9975433349609375
# TPR ： 0.9814814814814815
# TNR ： 1.0
# ACC ： 99.98502321401827
# PRE ： 1.0
# F1  ： 99.52893584087809
# 在数据集AES_T800.xlsx上的测试结果
# TIME： 0.9973049163818359
# TPR ： 0.9940119760479041
# TNR ： 1.0
# ACC ： 99.98540997957397
# PRE ： 1.0
# F1  ： 99.84611153209283
# 在数据集AES_T900.xlsx上的测试结果
# TIME： 1.966714859008789
# TPR ： 0.9978354978354979
# TNR ： 1.0
# ACC ： 99.98601202965449
# PRE ： 1.0
# F1  ： 99.94209050131124
# 在数据集AES_T1200.xlsx上的测试结果
# TIME： 1.9953250885009766
# TPR ： 0.9978354978354979
# TNR ： 1.0
# ACC ： 99.98601202965449
# PRE ： 1.0
# F1  ： 99.94209050131124
# 在数据集AES_T1300.xlsx上的测试结果
# TIME： 1.9946098327636719
# TPR ： 0.9814814814814815
# TNR ： 1.0
# ACC ： 99.98712169993561
# PRE ： 1.0
# F1  ： 99.52946836894286
# 在数据集AES_T1400.xlsx上的测试结果
# TIME： 1.9948482513427734
# TPR ： 0.9939393939393939
# TNR ： 1.0
# ACC ： 99.9918005903575
# PRE ： 1.0
# F1  ： 99.8459464372082
# 在数据集AES_T2000.xlsx上的测试结果
# TIME： 1.0249614715576172
# TPR ： 0.9939393939393939
# TNR ： 1.0
# ACC ： 99.98540572095739
# PRE ： 1.0
# F1  ： 99.84428599835242
# Original samples: 6915
# New samples: 11910
# 5926
# 在数据集AES_T400.xlsx上的测试结果
# TIME： 2.0236968994140625
# TPR ： 0.9871794871794872
# TNR ： 1.0
# ACC ： 99.98507685420086
# PRE ： 1.0
# F1  ： 99.67364491534298
# 在数据集AES_T700.xlsx上的测试结果
# TIME： 1.9941329956054688
# TPR ： 0.9814814814814815
# TNR ： 1.0
# ACC ： 99.98502321401827
# PRE ： 1.0
# F1  ： 99.52893584087809
# 在数据集AES_T800.xlsx上的测试结果
# TIME： 0.9973049163818359
# TPR ： 0.9940119760479041
# TNR ： 1.0
# ACC ： 99.98540997957397
# PRE ： 1.0
# F1  ： 99.84611153209283
# 在数据集AES_T900.xlsx上的测试结果
# TIME： 1.9946098327636719
# TPR ： 0.9978354978354979
# TNR ： 1.0
# ACC ： 99.98601202965449
# PRE ： 1.0
# F1  ： 99.94209050131124
# 在数据集AES_T1200.xlsx上的测试结果
# TIME： 1.9946098327636719
# TPR ： 0.9978354978354979
# TNR ： 1.0
# ACC ： 99.98601202965449
# PRE ： 1.0
# F1  ： 99.94209050131124
# 在数据集AES_T1300.xlsx上的测试结果
# TIME： 1.9946098327636719
# TPR ： 0.9814814814814815
# TNR ： 1.0
# ACC ： 99.98712169993561
# PRE ： 1.0
# F1  ： 99.52946836894286
# 在数据集AES_T1400.xlsx上的测试结果
# TIME： 1.9953250885009766
# TPR ： 0.9939393939393939
# TNR ： 1.0
# ACC ： 99.9918005903575
# PRE ： 1.0
# F1  ： 99.8459464372082
# 在数据集AES_T2000.xlsx上的测试结果
# TIME： 1.9943714141845703
# TPR ： 0.9939393939393939
# TNR ： 1.0
# ACC ： 99.98540572095739
# PRE ： 1.0
# F1  ： 99.84428599835242
# Original samples: 6915
# New samples: 11919
# 5935
# 在数据集AES_T400.xlsx上的测试结果
# TIME： 1.9640922546386719
# TPR ： 0.9871794871794872
# TNR ： 1.0
# ACC ： 99.98507685420086
# PRE ： 1.0
# F1  ： 99.67364491534298
# 在数据集AES_T700.xlsx上的测试结果
# TIME： 1.9946098327636719
# TPR ： 0.9814814814814815
# TNR ： 1.0
# ACC ： 99.98502321401827
# PRE ： 1.0
# F1  ： 99.52893584087809
# 在数据集AES_T800.xlsx上的测试结果
# TIME： 0.9970664978027344
# TPR ： 0.9940119760479041
# TNR ： 1.0
# ACC ： 99.98540997957397
# PRE ： 1.0
# F1  ： 99.84611153209283
# 在数据集AES_T900.xlsx上的测试结果
# TIME： 0.9973049163818359
# TPR ： 0.9978354978354979
# TNR ： 1.0
# ACC ： 99.98601202965449
# PRE ： 1.0
# F1  ： 99.94209050131124
# 在数据集AES_T1200.xlsx上的测试结果
# TIME： 1.9917488098144531
# TPR ： 0.9978354978354979
# TNR ： 1.0
# ACC ： 99.98601202965449
# PRE ： 1.0
# F1  ： 99.94209050131124
# 在数据集AES_T1300.xlsx上的测试结果
# TIME： 1.995086669921875
# TPR ： 0.9814814814814815
# TNR ： 1.0
# ACC ： 99.98712169993561
# PRE ： 1.0
# F1  ： 99.52946836894286
# 在数据集AES_T1400.xlsx上的测试结果
# TIME： 2.991914749145508
# TPR ： 0.9939393939393939
# TNR ： 1.0
# ACC ： 99.9918005903575
# PRE ： 1.0
# F1  ： 99.8459464372082
# 在数据集AES_T2000.xlsx上的测试结果
# TIME： 1.9948482513427734
# TPR ： 0.9939393939393939
# TNR ： 1.0
# ACC ： 99.98540572095739
# PRE ： 1.0
# F1  ： 99.84428599835242
# Original samples: 6915
# New samples: 11921
# 5937
# 在数据集AES_T400.xlsx上的测试结果
# TIME： 1.9943714141845703
# TPR ： 0.9871794871794872
# TNR ： 1.0
# ACC ： 99.98507685420086
# PRE ： 1.0
# F1  ： 99.67364491534298
# 在数据集AES_T700.xlsx上的测试结果
# TIME： 2.0012855529785156
# TPR ： 0.9814814814814815
# TNR ： 1.0
# ACC ： 99.98502321401827
# PRE ： 1.0
# F1  ： 99.52893584087809
# 在数据集AES_T800.xlsx上的测试结果
# TIME： 1.9946098327636719
# TPR ： 0.9940119760479041
# TNR ： 1.0
# ACC ： 99.98540997957397
# PRE ： 1.0
# F1  ： 99.84611153209283
# 在数据集AES_T900.xlsx上的测试结果
# TIME： 1.9943714141845703
# TPR ： 0.9978354978354979
# TNR ： 1.0
# ACC ： 99.98601202965449
# PRE ： 1.0
# F1  ： 99.94209050131124
# 在数据集AES_T1200.xlsx上的测试结果
# TIME： 1.9941329956054688
# TPR ： 0.9978354978354979
# TNR ： 1.0
# ACC ： 99.98601202965449
# PRE ： 1.0
# F1  ： 99.94209050131124
# 在数据集AES_T1300.xlsx上的测试结果
# TIME： 0.9982585906982422
# TPR ： 0.9814814814814815
# TNR ： 1.0
# ACC ： 99.98712169993561
# PRE ： 1.0
# F1  ： 99.52946836894286
# 在数据集AES_T1400.xlsx上的测试结果
# TIME： 2.992391586303711
# TPR ： 0.9939393939393939
# TNR ： 1.0
# ACC ： 99.9918005903575
# PRE ： 1.0
# F1  ： 99.8459464372082
# 在数据集AES_T2000.xlsx上的测试结果
# TIME： 1.9958019256591797
# TPR ： 0.9939393939393939
# TNR ： 1.0
# ACC ： 99.98540572095739
# PRE ： 1.0
# F1  ： 99.84428599835242
# Original samples: 6915
# New samples: 11920
# 5936
# 在数据集AES_T400.xlsx上的测试结果
# TIME： 0.9968280792236328
# TPR ： 0.9871794871794872
# TNR ： 1.0
# ACC ： 99.98507685420086
# PRE ： 1.0
# F1  ： 99.67364491534298
# 在数据集AES_T700.xlsx上的测试结果
# TIME： 0.9973049163818359
# TPR ： 0.9814814814814815
# TNR ： 1.0
# ACC ： 99.98502321401827
# PRE ： 1.0
# F1  ： 99.52893584087809
# 在数据集AES_T800.xlsx上的测试结果
# TIME： 0.9973049163818359
# TPR ： 0.9940119760479041
# TNR ： 1.0
# ACC ： 99.98540997957397
# PRE ： 1.0
# F1  ： 99.84611153209283
# 在数据集AES_T900.xlsx上的测试结果
# TIME： 0.9982585906982422
# TPR ： 0.9978354978354979
# TNR ： 1.0
# ACC ： 99.98601202965449
# PRE ： 1.0
# F1  ： 99.94209050131124
# 在数据集AES_T1200.xlsx上的测试结果
# TIME： 2.022266387939453
# TPR ： 0.9978354978354979
# TNR ： 1.0
# ACC ： 99.98601202965449
# PRE ： 1.0
# F1  ： 99.94209050131124
# 在数据集AES_T1300.xlsx上的测试结果
# TIME： 2.0227432250976562
# TPR ： 0.9814814814814815
# TNR ： 1.0
# ACC ： 99.98712169993561
# PRE ： 1.0
# F1  ： 99.52946836894286
# 在数据集AES_T1400.xlsx上的测试结果
# TIME： 2.9888153076171875
# TPR ： 0.9939393939393939
# TNR ： 1.0
# ACC ： 99.9918005903575
# PRE ： 1.0
# F1  ： 99.8459464372082
# 在数据集AES_T2000.xlsx上的测试结果
# TIME： 1.9953250885009766
# TPR ： 0.9939393939393939
# TNR ： 1.0
# ACC ： 99.98540572095739
# PRE ： 1.0
# F1  ： 99.84428599835242
# Original samples: 6915
# New samples: 11920
# 5936
# 在数据集AES_T400.xlsx上的测试结果
# TIME： 1.9946098327636719
# TPR ： 0.9871794871794872
# TNR ： 1.0
# ACC ： 99.98507685420086
# PRE ： 1.0
# F1  ： 99.67364491534298
# 在数据集AES_T700.xlsx上的测试结果
# TIME： 2.0227432250976562
# TPR ： 0.9814814814814815
# TNR ： 1.0
# ACC ： 99.98502321401827
# PRE ： 1.0
# F1  ： 99.52893584087809
# 在数据集AES_T800.xlsx上的测试结果
# TIME： 2.9921531677246094
# TPR ： 0.9940119760479041
# TNR ： 1.0
# ACC ： 99.98540997957397
# PRE ： 1.0
# F1  ： 99.84611153209283
# 在数据集AES_T900.xlsx上的测试结果
# TIME： 0.9970664978027344
# TPR ： 0.9978354978354979
# TNR ： 1.0
# ACC ： 99.98601202965449
# PRE ： 1.0
# F1  ： 99.94209050131124
# 在数据集AES_T1200.xlsx上的测试结果
# TIME： 1.9943714141845703
# TPR ： 0.9978354978354979
# TNR ： 1.0
# ACC ： 99.98601202965449
# PRE ： 1.0
# F1  ： 99.94209050131124
# 在数据集AES_T1300.xlsx上的测试结果
# TIME： 1.995086669921875
# TPR ： 0.9814814814814815
# TNR ： 1.0
# ACC ： 99.98712169993561
# PRE ： 1.0
# F1  ： 99.52946836894286
# 在数据集AES_T1400.xlsx上的测试结果
# TIME： 2.991914749145508
# TPR ： 0.9939393939393939
# TNR ： 1.0
# ACC ： 99.9918005903575
# PRE ： 1.0
# F1  ： 99.8459464372082
# 在数据集AES_T2000.xlsx上的测试结果
# TIME： 1.9948482513427734
# TPR ： 0.9939393939393939
# TNR ： 1.0
# ACC ： 99.98540572095739
# PRE ： 1.0
# F1  ： 99.84428599835242
# Original samples: 6915
# New samples: 11929
# 5945
# 在数据集AES_T400.xlsx上的测试结果
# TIME： 0.9996891021728516
# TPR ： 0.9871794871794872
# TNR ： 1.0
# ACC ： 99.98507685420086
# PRE ： 1.0
# F1  ： 99.67364491534298
# 在数据集AES_T700.xlsx上的测试结果
# TIME： 1.9943714141845703
# TPR ： 0.9814814814814815
# TNR ： 1.0
# ACC ： 99.98502321401827
# PRE ： 1.0
# F1  ： 99.52893584087809
# 在数据集AES_T800.xlsx上的测试结果
# TIME： 1.9941329956054688
# TPR ： 0.9940119760479041
# TNR ： 1.0
# ACC ： 99.98540997957397
# PRE ： 1.0
# F1  ： 99.84611153209283
# 在数据集AES_T900.xlsx上的测试结果
# TIME： 1.9946098327636719
# TPR ： 0.9978354978354979
# TNR ： 1.0
# ACC ： 99.98601202965449
# PRE ： 1.0
# F1  ： 99.94209050131124
# 在数据集AES_T1200.xlsx上的测试结果
# TIME： 1.9941329956054688
# TPR ： 0.9978354978354979
# TNR ： 1.0
# ACC ： 99.98601202965449
# PRE ： 1.0
# F1  ： 99.94209050131124
# 在数据集AES_T1300.xlsx上的测试结果
# TIME： 1.9948482513427734
# TPR ： 0.9814814814814815
# TNR ： 1.0
# ACC ： 99.98712169993561
# PRE ： 1.0
# F1  ： 99.52946836894286
# 在数据集AES_T1400.xlsx上的测试结果
# TIME： 4.017353057861328
# TPR ： 0.9939393939393939
# TNR ： 1.0
# ACC ： 99.9918005903575
# PRE ： 1.0
# F1  ： 99.8459464372082
# 在数据集AES_T2000.xlsx上的测试结果
# TIME： 1.995086669921875
# TPR ： 0.9939393939393939
# TNR ： 1.0
# ACC ： 99.98540572095739
# PRE ： 1.0
# F1  ： 99.84428599835242
# Original samples: 6915
# New samples: 11920
# 5936
# 在数据集AES_T400.xlsx上的测试结果
# TIME： 0.9968280792236328
# TPR ： 0.9871794871794872
# TNR ： 1.0
# ACC ： 99.98507685420086
# PRE ： 1.0
# F1  ： 99.67364491534298
# 在数据集AES_T700.xlsx上的测试结果
# TIME： 1.9946098327636719
# TPR ： 0.9814814814814815
# TNR ： 1.0
# ACC ： 99.98502321401827
# PRE ： 1.0
# F1  ： 99.52893584087809
# 在数据集AES_T800.xlsx上的测试结果
# TIME： 1.9941329956054688
# TPR ： 0.9940119760479041
# TNR ： 1.0
# ACC ： 99.98540997957397
# PRE ： 1.0
# F1  ： 99.84611153209283
# 在数据集AES_T900.xlsx上的测试结果
# TIME： 0.9975433349609375
# TPR ： 0.9978354978354979
# TNR ： 1.0
# ACC ： 99.98601202965449
# PRE ： 1.0
# F1  ： 99.94209050131124
# 在数据集AES_T1200.xlsx上的测试结果
# TIME： 1.9946098327636719
# TPR ： 0.9978354978354979
# TNR ： 1.0
# ACC ： 99.98601202965449
# PRE ： 1.0
# F1  ： 99.94209050131124
# 在数据集AES_T1300.xlsx上的测试结果
# TIME： 1.9948482513427734
# TPR ： 0.9814814814814815
# TNR ： 1.0
# ACC ： 99.98712169993561
# PRE ： 1.0
# F1  ： 99.52946836894286
# 在数据集AES_T1400.xlsx上的测试结果
# TIME： 3.0198097229003906
# TPR ： 0.9939393939393939
# TNR ： 1.0
# ACC ： 99.9918005903575
# PRE ： 1.0
# F1  ： 99.8459464372082
# 在数据集AES_T2000.xlsx上的测试结果
# TIME： 2.0225048065185547
# TPR ： 0.9939393939393939
# TNR ： 1.0
# ACC ： 99.98540572095739
# PRE ： 1.0
# F1  ： 99.84428599835242
# Original samples: 6915
# New samples: 11909
# 5925
# 在数据集AES_T400.xlsx上的测试结果
# TIME： 1.9941329956054688
# TPR ： 0.9871794871794872
# TNR ： 1.0
# ACC ： 99.98507685420086
# PRE ： 1.0
# F1  ： 99.67364491534298
# 在数据集AES_T700.xlsx上的测试结果
# TIME： 1.9946098327636719
# TPR ： 0.9814814814814815
# TNR ： 1.0
# ACC ： 99.98502321401827
# PRE ： 1.0
# F1  ： 99.52893584087809
# 在数据集AES_T800.xlsx上的测试结果
# TIME： 1.9948482513427734
# TPR ： 0.9940119760479041
# TNR ： 1.0
# ACC ： 99.98540997957397
# PRE ： 1.0
# F1  ： 99.84611153209283
# 在数据集AES_T900.xlsx上的测试结果
# TIME： 1.9671916961669922
# TPR ： 0.9978354978354979
# TNR ： 1.0
# ACC ： 99.98601202965449
# PRE ： 1.0
# F1  ： 99.94209050131124
# 在数据集AES_T1200.xlsx上的测试结果
# TIME： 0.9977817535400391
# TPR ： 0.9978354978354979
# TNR ： 1.0
# ACC ： 99.98601202965449
# PRE ： 1.0
# F1  ： 99.94209050131124
# 在数据集AES_T1300.xlsx上的测试结果
# TIME： 2.0227432250976562
# TPR ： 0.9814814814814815
# TNR ： 1.0
# ACC ： 99.98712169993561
# PRE ： 1.0
# F1  ： 99.52946836894286
# 在数据集AES_T1400.xlsx上的测试结果
# TIME： 2.9892921447753906
# TPR ： 0.9939393939393939
# TNR ： 1.0
# ACC ： 99.9918005903575
# PRE ： 1.0
# F1  ： 99.8459464372082
# 在数据集AES_T2000.xlsx上的测试结果
# TIME： 1.9946098327636719
# TPR ： 0.9939393939393939
# TNR ： 1.0
# ACC ： 99.98540572095739
# PRE ： 1.0
# F1  ： 99.84428599835242
# Original samples: 6915
# New samples: 11921
# 5937
# 在数据集AES_T400.xlsx上的测试结果
# TIME： 1.9946098327636719
# TPR ： 0.9871794871794872
# TNR ： 1.0
# ACC ： 99.98507685420086
# PRE ： 1.0
# F1  ： 99.67364491534298
# 在数据集AES_T700.xlsx上的测试结果
# TIME： 0.9975433349609375
# TPR ： 0.9814814814814815
# TNR ： 1.0
# ACC ： 99.98502321401827
# PRE ： 1.0
# F1  ： 99.52893584087809
# 在数据集AES_T800.xlsx上的测试结果
# TIME： 1.0178089141845703
# TPR ： 0.9940119760479041
# TNR ： 1.0
# ACC ： 99.98540997957397
# PRE ： 1.0
# F1  ： 99.84611153209283
# 在数据集AES_T900.xlsx上的测试结果
# TIME： 2.023458480834961
# TPR ： 0.9978354978354979
# TNR ： 1.0
# ACC ： 99.98601202965449
# PRE ： 1.0
# F1  ： 99.94209050131124
# 在数据集AES_T1200.xlsx上的测试结果
# TIME： 1.9943714141845703
# TPR ： 0.9978354978354979
# TNR ： 1.0
# ACC ： 99.98601202965449
# PRE ： 1.0
# F1  ： 99.94209050131124
# 在数据集AES_T1300.xlsx上的测试结果
# TIME： 1.9669532775878906
# TPR ： 0.9814814814814815
# TNR ： 1.0
# ACC ： 99.98712169993561
# PRE ： 1.0
# F1  ： 99.52946836894286
# 在数据集AES_T1400.xlsx上的测试结果
# TIME： 1.9636154174804688
# TPR ： 0.9939393939393939
# TNR ： 1.0
# ACC ： 99.9918005903575
# PRE ： 1.0
# F1  ： 99.8459464372082
# 在数据集AES_T2000.xlsx上的测试结果
# TIME： 1.9943714141845703
# TPR ： 0.9939393939393939
# TNR ： 1.0
# ACC ： 99.98540572095739
# PRE ： 1.0
# F1  ： 99.84428599835242
# Original samples: 6915
# New samples: 11909
# 5925
# 在数据集AES_T400.xlsx上的测试结果
# TIME： 0.9973049163818359
# TPR ： 0.9871794871794872
# TNR ： 1.0
# ACC ： 99.98507685420086
# PRE ： 1.0
# F1  ： 99.67364491534298
# 在数据集AES_T700.xlsx上的测试结果
# TIME： 0.9670257568359375
# TPR ： 0.9814814814814815
# TNR ： 1.0
# ACC ： 99.98502321401827
# PRE ： 1.0
# F1  ： 99.52893584087809
# 在数据集AES_T800.xlsx上的测试结果
# TIME： 0.9970664978027344
# TPR ： 0.9940119760479041
# TNR ： 1.0
# ACC ： 99.98540997957397
# PRE ： 1.0
# F1  ： 99.84611153209283
# 在数据集AES_T900.xlsx上的测试结果
# TIME： 1.9943714141845703
# TPR ： 0.9978354978354979
# TNR ： 1.0
# ACC ： 99.98601202965449
# PRE ： 1.0
# F1  ： 99.94209050131124
# 在数据集AES_T1200.xlsx上的测试结果
# TIME： 1.9605159759521484
# TPR ： 0.9978354978354979
# TNR ： 1.0
# ACC ： 99.98601202965449
# PRE ： 1.0
# F1  ： 99.94209050131124
# 在数据集AES_T1300.xlsx上的测试结果
# TIME： 2.0248889923095703
# TPR ： 0.9814814814814815
# TNR ： 1.0
# ACC ： 99.98712169993561
# PRE ： 1.0
# F1  ： 99.52946836894286
# 在数据集AES_T1400.xlsx上的测试结果
# TIME： 2.991914749145508
# TPR ： 0.9939393939393939
# TNR ： 1.0
# ACC ： 99.9918005903575
# PRE ： 1.0
# F1  ： 99.8459464372082
# 在数据集AES_T2000.xlsx上的测试结果
# TIME： 1.9946098327636719
# TPR ： 0.9939393939393939
# TNR ： 1.0
# ACC ： 99.98540572095739
# PRE ： 1.0
# F1  ： 99.84428599835242
# Original samples: 6915
# New samples: 11905
# 5921
# 在数据集AES_T400.xlsx上的测试结果
# TIME： 1.9941329956054688
# TPR ： 0.9871794871794872
# TNR ： 1.0
# ACC ： 99.98507685420086
# PRE ： 1.0
# F1  ： 99.67364491534298
# 在数据集AES_T700.xlsx上的测试结果
# TIME： 0.9973049163818359
# TPR ： 0.9814814814814815
# TNR ： 1.0
# ACC ： 99.98502321401827
# PRE ： 1.0
# F1  ： 99.52893584087809
# 在数据集AES_T800.xlsx上的测试结果
# TIME： 2.000570297241211
# TPR ： 0.9940119760479041
# TNR ： 1.0
# ACC ： 99.98540997957397
# PRE ： 1.0
# F1  ： 99.84611153209283
# 在数据集AES_T900.xlsx上的测试结果
# TIME： 1.9948482513427734
# TPR ： 0.9978354978354979
# TNR ： 1.0
# ACC ： 99.98601202965449
# PRE ： 1.0
# F1  ： 99.94209050131124
# 在数据集AES_T1200.xlsx上的测试结果
# TIME： 1.9948482513427734
# TPR ： 0.9978354978354979
# TNR ： 1.0
# ACC ： 99.98601202965449
# PRE ： 1.0
# F1  ： 99.94209050131124
# 在数据集AES_T1300.xlsx上的测试结果
# TIME： 0.9944438934326172
# TPR ： 0.9814814814814815
# TNR ： 1.0
# ACC ： 99.98712169993561
# PRE ： 1.0
# F1  ： 99.52946836894286
# 在数据集AES_T1400.xlsx上的测试结果
# TIME： 2.991914749145508
# TPR ： 0.9939393939393939
# TNR ： 1.0
# ACC ： 99.9918005903575
# PRE ： 1.0
# F1  ： 99.8459464372082
# 在数据集AES_T2000.xlsx上的测试结果
# TIME： 0.9970664978027344
# TPR ： 0.9939393939393939
# TNR ： 1.0
# ACC ： 99.98540572095739
# PRE ： 1.0
# F1  ： 99.84428599835242
# Original samples: 6915
# New samples: 11926
# 5942
# 在数据集AES_T400.xlsx上的测试结果
# TIME： 0.9970664978027344
# TPR ： 0.9871794871794872
# TNR ： 1.0
# ACC ： 99.98507685420086
# PRE ： 1.0
# F1  ： 99.67364491534298
# 在数据集AES_T700.xlsx上的测试结果
# TIME： 1.9943714141845703
# TPR ： 0.9814814814814815
# TNR ： 1.0
# ACC ： 99.98502321401827
# PRE ： 1.0
# F1  ： 99.52893584087809
# 在数据集AES_T800.xlsx上的测试结果
# TIME： 1.9943714141845703
# TPR ： 0.9940119760479041
# TNR ： 1.0
# ACC ： 99.98540997957397
# PRE ： 1.0
# F1  ： 99.84611153209283
# 在数据集AES_T900.xlsx上的测试结果
# TIME： 2.000570297241211
# TPR ： 0.9978354978354979
# TNR ： 1.0
# ACC ： 99.98601202965449
# PRE ： 1.0
# F1  ： 99.94209050131124
# 在数据集AES_T1200.xlsx上的测试结果
# TIME： 1.9974708557128906
# TPR ： 0.9978354978354979
# TNR ： 1.0
# ACC ： 99.98601202965449
# PRE ： 1.0
# F1  ： 99.94209050131124
# 在数据集AES_T1300.xlsx上的测试结果
# TIME： 1.9910335540771484
# TPR ： 0.9814814814814815
# TNR ： 1.0
# ACC ： 99.98712169993561
# PRE ： 1.0
# F1  ： 99.52946836894286
# 在数据集AES_T1400.xlsx上的测试结果
# TIME： 1.9969940185546875
# TPR ： 0.9939393939393939
# TNR ： 1.0
# ACC ： 99.9918005903575
# PRE ： 1.0
# F1  ： 99.8459464372082
# 在数据集AES_T2000.xlsx上的测试结果
# TIME： 1.9941329956054688
# TPR ： 0.9939393939393939
# TNR ： 1.0
# ACC ： 99.98540572095739
# PRE ： 1.0
# F1  ： 99.84428599835242
# Original samples: 6915
# New samples: 11907
# 5923
# 在数据集AES_T400.xlsx上的测试结果
# TIME： 0.9975433349609375
# TPR ： 0.9871794871794872
# TNR ： 1.0
# ACC ： 99.98507685420086
# PRE ： 1.0
# F1  ： 99.67364491534298
# 在数据集AES_T700.xlsx上的测试结果
# TIME： 1.995086669921875
# TPR ： 0.9814814814814815
# TNR ： 1.0
# ACC ： 99.98502321401827
# PRE ： 1.0
# F1  ： 99.52893584087809
# 在数据集AES_T800.xlsx上的测试结果
# TIME： 0.9973049163818359
# TPR ： 0.9940119760479041
# TNR ： 1.0
# ACC ： 99.98540997957397
# PRE ： 1.0
# F1  ： 99.84611153209283
# 在数据集AES_T900.xlsx上的测试结果
# TIME： 2.0275115966796875
# TPR ： 0.9978354978354979
# TNR ： 1.0
# ACC ： 99.98601202965449
# PRE ： 1.0
# F1  ： 99.94209050131124
# 在数据集AES_T1200.xlsx上的测试结果
# TIME： 0.9973049163818359
# TPR ： 0.9978354978354979
# TNR ： 1.0
# ACC ： 99.98601202965449
# PRE ： 1.0
# F1  ： 99.94209050131124
# 在数据集AES_T1300.xlsx上的测试结果
# TIME： 1.9946098327636719
# TPR ： 0.9814814814814815
# TNR ： 1.0
# ACC ： 99.98712169993561
# PRE ： 1.0
# F1  ： 99.52946836894286
# 在数据集AES_T1400.xlsx上的测试结果
# TIME： 1.9946098327636719
# TPR ： 0.9939393939393939
# TNR ： 1.0
# ACC ： 99.9918005903575
# PRE ： 1.0
# F1  ： 99.8459464372082
# 在数据集AES_T2000.xlsx上的测试结果
# TIME： 1.9948482513427734
# TPR ： 0.9939393939393939
# TNR ： 1.0
# ACC ： 99.98540572095739
# PRE ： 1.0
# F1  ： 99.84428599835242
# Original samples: 6915
# New samples: 11918
# 5934
# 在数据集AES_T400.xlsx上的测试结果
# TIME： 0.99945068359375
# TPR ： 0.9871794871794872
# TNR ： 1.0
# ACC ： 99.98507685420086
# PRE ： 1.0
# F1  ： 99.67364491534298
# 在数据集AES_T700.xlsx上的测试结果
# TIME： 1.9941329956054688
# TPR ： 0.9814814814814815
# TNR ： 1.0
# ACC ： 99.98502321401827
# PRE ： 1.0
# F1  ： 99.52893584087809
# 在数据集AES_T800.xlsx上的测试结果
# TIME： 1.9948482513427734
# TPR ： 0.9940119760479041
# TNR ： 1.0
# ACC ： 99.98540997957397
# PRE ： 1.0
# F1  ： 99.84611153209283
# 在数据集AES_T900.xlsx上的测试结果
# TIME： 1.995086669921875
# TPR ： 0.9978354978354979
# TNR ： 1.0
# ACC ： 99.98601202965449
# PRE ： 1.0
# F1  ： 99.94209050131124
# 在数据集AES_T1200.xlsx上的测试结果
# TIME： 1.9948482513427734
# TPR ： 0.9978354978354979
# TNR ： 1.0
# ACC ： 99.98601202965449
# PRE ： 1.0
# F1  ： 99.94209050131124
# 在数据集AES_T1300.xlsx上的测试结果
# TIME： 1.995086669921875
# TPR ： 0.9814814814814815
# TNR ： 1.0
# ACC ： 99.98712169993561
# PRE ： 1.0
# F1  ： 99.52946836894286
# 在数据集AES_T1400.xlsx上的测试结果
# TIME： 2.9914379119873047
# TPR ： 0.9939393939393939
# TNR ： 1.0
# ACC ： 99.9918005903575
# PRE ： 1.0
# F1  ： 99.8459464372082
# 在数据集AES_T2000.xlsx上的测试结果
# TIME： 1.9941329956054688
# TPR ： 0.9939393939393939
# TNR ： 1.0
# ACC ： 99.98540572095739
# PRE ： 1.0
# F1  ： 99.84428599835242
# Original samples: 6915
# New samples: 11920
# 5936
# 在数据集AES_T400.xlsx上的测试结果
# TIME： 1.9948482513427734
# TPR ： 0.9871794871794872
# TNR ： 1.0
# ACC ： 99.98507685420086
# PRE ： 1.0
# F1  ： 99.67364491534298
# 在数据集AES_T700.xlsx上的测试结果
# TIME： 1.995086669921875
# TPR ： 0.9814814814814815
# TNR ： 1.0
# ACC ： 99.98502321401827
# PRE ： 1.0
# F1  ： 99.52893584087809
# 在数据集AES_T800.xlsx上的测试结果
# TIME： 0.9980201721191406
# TPR ： 0.9940119760479041
# TNR ： 1.0
# ACC ： 99.98540997957397
# PRE ： 1.0
# F1  ： 99.84611153209283
# 在数据集AES_T900.xlsx上的测试结果
# TIME： 0.9977817535400391
# TPR ： 0.9978354978354979
# TNR ： 1.0
# ACC ： 99.98601202965449
# PRE ： 1.0
# F1  ： 99.94209050131124
# 在数据集AES_T1200.xlsx上的测试结果
# TIME： 0.9958744049072266
# TPR ： 0.9978354978354979
# TNR ： 1.0
# ACC ： 99.98601202965449
# PRE ： 1.0
# F1  ： 99.94209050131124
# 在数据集AES_T1300.xlsx上的测试结果
# TIME： 0.9977817535400391
# TPR ： 0.9814814814814815
# TNR ： 1.0
# ACC ： 99.98712169993561
# PRE ： 1.0
# F1  ： 99.52946836894286
# 在数据集AES_T1400.xlsx上的测试结果
# TIME： 2.991914749145508
# TPR ： 0.9939393939393939
# TNR ： 1.0
# ACC ： 99.9918005903575
# PRE ： 1.0
# F1  ： 99.8459464372082
# 在数据集AES_T2000.xlsx上的测试结果
# TIME： 2.022981643676758
# TPR ： 0.9939393939393939
# TNR ： 1.0
# ACC ： 99.98540572095739
# PRE ： 1.0
# F1  ： 99.84428599835242
# Original samples: 6915
# New samples: 11923
# 5939
# 在数据集AES_T400.xlsx上的测试结果
# TIME： 0.9977817535400391
# TPR ： 0.9871794871794872
# TNR ： 1.0
# ACC ： 99.98507685420086
# PRE ： 1.0
# F1  ： 99.67364491534298
# 在数据集AES_T700.xlsx上的测试结果
# TIME： 0.9975433349609375
# TPR ： 0.9814814814814815
# TNR ： 1.0
# ACC ： 99.98502321401827
# PRE ： 1.0
# F1  ： 99.52893584087809
# 在数据集AES_T800.xlsx上的测试结果
# TIME： 1.9946098327636719
# TPR ： 0.9940119760479041
# TNR ： 1.0
# ACC ： 99.98540997957397
# PRE ： 1.0
# F1  ： 99.84611153209283
# 在数据集AES_T900.xlsx上的测试结果
# TIME： 1.9948482513427734
# TPR ： 0.9978354978354979
# TNR ： 1.0
# ACC ： 99.98601202965449
# PRE ： 1.0
# F1  ： 99.94209050131124
# 在数据集AES_T1200.xlsx上的测试结果
# TIME： 1.995086669921875
# TPR ： 0.9978354978354979
# TNR ： 1.0
# ACC ： 99.98601202965449
# PRE ： 1.0
# F1  ： 99.94209050131124
# 在数据集AES_T1300.xlsx上的测试结果
# TIME： 1.9953250885009766
# TPR ： 0.9814814814814815
# TNR ： 1.0
# ACC ： 99.98712169993561
# PRE ： 1.0
# F1  ： 99.52946836894286
# 在数据集AES_T1400.xlsx上的测试结果
# TIME： 3.020048141479492
# TPR ： 0.9939393939393939
# TNR ： 1.0
# ACC ： 99.9918005903575
# PRE ： 1.0
# F1  ： 99.8459464372082
# 在数据集AES_T2000.xlsx上的测试结果
# TIME： 1.9903182983398438
# TPR ： 0.9939393939393939
# TNR ： 1.0
# ACC ： 99.98540572095739
# PRE ： 1.0
# F1  ： 99.84428599835242
# Original samples: 6915
# New samples: 11913
# 5929
# 在数据集AES_T400.xlsx上的测试结果
# TIME： 1.9948482513427734
# TPR ： 0.9871794871794872
# TNR ： 1.0
# ACC ： 99.98507685420086
# PRE ： 1.0
# F1  ： 99.67364491534298
# 在数据集AES_T700.xlsx上的测试结果
# TIME： 2.025127410888672
# TPR ： 0.9814814814814815
# TNR ： 1.0
# ACC ： 99.98502321401827
# PRE ： 1.0
# F1  ： 99.52893584087809
# 在数据集AES_T800.xlsx上的测试结果
# TIME： 1.995086669921875
# TPR ： 0.9940119760479041
# TNR ： 1.0
# ACC ： 99.98540997957397
# PRE ： 1.0
# F1  ： 99.84611153209283
# 在数据集AES_T900.xlsx上的测试结果
# TIME： 1.9965171813964844
# TPR ： 0.9978354978354979
# TNR ： 1.0
# ACC ： 99.98601202965449
# PRE ： 1.0
# F1  ： 99.94209050131124
# 在数据集AES_T1200.xlsx上的测试结果
# TIME： 1.966714859008789
# TPR ： 0.9978354978354979
# TNR ： 1.0
# ACC ： 99.98601202965449
# PRE ： 1.0
# F1  ： 99.94209050131124
# 在数据集AES_T1300.xlsx上的测试结果
# TIME： 1.9943714141845703
# TPR ： 0.9814814814814815
# TNR ： 1.0
# ACC ： 99.98712169993561
# PRE ： 1.0
# F1  ： 99.52946836894286
# 在数据集AES_T1400.xlsx上的测试结果
# TIME： 3.020048141479492
# TPR ： 0.9939393939393939
# TNR ： 1.0
# ACC ： 99.9918005903575
# PRE ： 1.0
# F1  ： 99.8459464372082
# 在数据集AES_T2000.xlsx上的测试结果
# TIME： 1.9948482513427734
# TPR ： 0.9939393939393939
# TNR ： 1.0
# ACC ： 99.98540572095739
# PRE ： 1.0
# F1  ： 99.84428599835242
# Original samples: 6915
# New samples: 11913
# 5929
# 在数据集AES_T400.xlsx上的测试结果
# TIME： 1.9941329956054688
# TPR ： 0.9871794871794872
# TNR ： 1.0
# ACC ： 99.98507685420086
# PRE ： 1.0
# F1  ： 99.67364491534298
# 在数据集AES_T700.xlsx上的测试结果
# TIME： 1.9943714141845703
# TPR ： 0.9814814814814815
# TNR ： 1.0
# ACC ： 99.98502321401827
# PRE ： 1.0
# F1  ： 99.52893584087809
# 在数据集AES_T800.xlsx上的测试结果
# TIME： 1.995086669921875
# TPR ： 0.9940119760479041
# TNR ： 1.0
# ACC ： 99.98540997957397
# PRE ： 1.0
# F1  ： 99.84611153209283
# 在数据集AES_T900.xlsx上的测试结果
# TIME： 0.9973049163818359
# TPR ： 0.9978354978354979
# TNR ： 1.0
# ACC ： 99.98601202965449
# PRE ： 1.0
# F1  ： 99.94209050131124
# 在数据集AES_T1200.xlsx上的测试结果
# TIME： 1.9943714141845703
# TPR ： 0.9978354978354979
# TNR ： 1.0
# ACC ： 99.98601202965449
# PRE ： 1.0
# F1  ： 99.94209050131124
# 在数据集AES_T1300.xlsx上的测试结果
# TIME： 1.9657611846923828
# TPR ： 0.9814814814814815
# TNR ： 1.0
# ACC ： 99.98712169993561
# PRE ： 1.0
# F1  ： 99.52946836894286
# 在数据集AES_T1400.xlsx上的测试结果
# TIME： 2.991914749145508
# TPR ： 0.9939393939393939
# TNR ： 1.0
# ACC ： 99.9918005903575
# PRE ： 1.0
# F1  ： 99.8459464372082
# 在数据集AES_T2000.xlsx上的测试结果
# TIME： 1.995086669921875
# TPR ： 0.9939393939393939
# TNR ： 1.0
# ACC ： 99.98540572095739
# PRE ： 1.0
# F1  ： 99.84428599835242
# Original samples: 6915
# New samples: 11927
# 5943
# 在数据集AES_T400.xlsx上的测试结果
# TIME： 1.995086669921875
# TPR ： 0.9871794871794872
# TNR ： 1.0
# ACC ： 99.98507685420086
# PRE ： 1.0
# F1  ： 99.67364491534298
# 在数据集AES_T700.xlsx上的测试结果
# TIME： 1.995086669921875
# TPR ： 0.9814814814814815
# TNR ： 1.0
# ACC ： 99.98502321401827
# PRE ： 1.0
# F1  ： 99.52893584087809
# 在数据集AES_T800.xlsx上的测试结果
# TIME： 1.9946098327636719
# TPR ： 0.9940119760479041
# TNR ： 1.0
# ACC ： 99.98540997957397
# PRE ： 1.0
# F1  ： 99.84611153209283
# 在数据集AES_T900.xlsx上的测试结果
# TIME： 1.9941329956054688
# TPR ： 0.9978354978354979
# TNR ： 1.0
# ACC ： 99.98601202965449
# PRE ： 1.0
# F1  ： 99.94209050131124
# 在数据集AES_T1200.xlsx上的测试结果
# TIME： 1.9943714141845703
# TPR ： 0.9978354978354979
# TNR ： 1.0
# ACC ： 99.98601202965449
# PRE ： 1.0
# F1  ： 99.94209050131124
# 在数据集AES_T1300.xlsx上的测试结果
# TIME： 1.9943714141845703
# TPR ： 0.9814814814814815
# TNR ： 1.0
# ACC ： 99.98712169993561
# PRE ： 1.0
# F1  ： 99.52946836894286
# 在数据集AES_T1400.xlsx上的测试结果
# TIME： 2.964019775390625
# TPR ： 0.9939393939393939
# TNR ： 1.0
# ACC ： 99.9918005903575
# PRE ： 1.0
# F1  ： 99.8459464372082
# 在数据集AES_T2000.xlsx上的测试结果
# TIME： 1.9948482513427734
# TPR ： 0.9939393939393939
# TNR ： 1.0
# ACC ： 99.98540572095739
# PRE ： 1.0
# F1  ： 99.84428599835242
# Original samples: 6915
# New samples: 11905
# 5921
# 在数据集AES_T400.xlsx上的测试结果
# TIME： 0.9639263153076172
# TPR ： 0.9871794871794872
# TNR ： 1.0
# ACC ： 99.98507685420086
# PRE ： 1.0
# F1  ： 99.67364491534298
# 在数据集AES_T700.xlsx上的测试结果
# TIME： 1.9936561584472656
# TPR ： 0.9814814814814815
# TNR ： 1.0
# ACC ： 99.98502321401827
# PRE ： 1.0
# F1  ： 99.52893584087809
# 在数据集AES_T800.xlsx上的测试结果
# TIME： 2.001047134399414
# TPR ： 0.9940119760479041
# TNR ： 1.0
# ACC ： 99.98540997957397
# PRE ： 1.0
# F1  ： 99.84611153209283
# 在数据集AES_T900.xlsx上的测试结果
# TIME： 1.9946098327636719
# TPR ： 0.9978354978354979
# TNR ： 1.0
# ACC ： 99.98601202965449
# PRE ： 1.0
# F1  ： 99.94209050131124
# 在数据集AES_T1200.xlsx上的测试结果
# TIME： 1.9922256469726562
# TPR ： 0.9978354978354979
# TNR ： 1.0
# ACC ： 99.98601202965449
# PRE ： 1.0
# F1  ： 99.94209050131124
# 在数据集AES_T1300.xlsx上的测试结果
# TIME： 2.0227432250976562
# TPR ： 0.9814814814814815
# TNR ： 1.0
# ACC ： 99.98712169993561
# PRE ： 1.0
# F1  ： 99.52946836894286
# 在数据集AES_T1400.xlsx上的测试结果
# TIME： 2.0225048065185547
# TPR ： 0.9939393939393939
# TNR ： 1.0
# ACC ： 99.9918005903575
# PRE ： 1.0
# F1  ： 99.8459464372082
# 在数据集AES_T2000.xlsx上的测试结果
# TIME： 1.9946098327636719
# TPR ： 0.9939393939393939
# TNR ： 1.0
# ACC ： 99.98540572095739
# PRE ： 1.0
# F1  ： 99.84428599835242
# Original samples: 6915
# New samples: 11917
# 5933
# 在数据集AES_T400.xlsx上的测试结果
# TIME： 0.9975433349609375
# TPR ： 0.9871794871794872
# TNR ： 1.0
# ACC ： 99.98507685420086
# PRE ： 1.0
# F1  ： 99.67364491534298
# 在数据集AES_T700.xlsx上的测试结果
# TIME： 1.9948482513427734
# TPR ： 0.9814814814814815
# TNR ： 1.0
# ACC ： 99.98502321401827
# PRE ： 1.0
# F1  ： 99.52893584087809
# 在数据集AES_T800.xlsx上的测试结果
# TIME： 0.9975433349609375
# TPR ： 0.9940119760479041
# TNR ： 1.0
# ACC ： 99.98540997957397
# PRE ： 1.0
# F1  ： 99.84611153209283
# 在数据集AES_T900.xlsx上的测试结果
# TIME： 1.9943714141845703
# TPR ： 0.9978354978354979
# TNR ： 1.0
# ACC ： 99.98601202965449
# PRE ： 1.0
# F1  ： 99.94209050131124
# 在数据集AES_T1200.xlsx上的测试结果
# TIME： 1.9946098327636719
# TPR ： 0.9978354978354979
# TNR ： 1.0
# ACC ： 99.98601202965449
# PRE ： 1.0
# F1  ： 99.94209050131124
# 在数据集AES_T1300.xlsx上的测试结果
# TIME： 1.9674301147460938
# TPR ： 0.9814814814814815
# TNR ： 1.0
# ACC ： 99.98712169993561
# PRE ： 1.0
# F1  ： 99.52946836894286
# 在数据集AES_T1400.xlsx上的测试结果
# TIME： 2.9921531677246094
# TPR ： 0.9939393939393939
# TNR ： 1.0
# ACC ： 99.9918005903575
# PRE ： 1.0
# F1  ： 99.8459464372082
# 在数据集AES_T2000.xlsx上的测试结果
# TIME： 1.9948482513427734
# TPR ： 0.9939393939393939
# TNR ： 1.0
# ACC ： 99.98540572095739
# PRE ： 1.0
# F1  ： 99.84428599835242
# Original samples: 6915
# New samples: 11912
# 5928
# 在数据集AES_T400.xlsx上的测试结果
# TIME： 1.0001659393310547
# TPR ： 0.9871794871794872
# TNR ： 1.0
# ACC ： 99.98507685420086
# PRE ： 1.0
# F1  ： 99.67364491534298
# 在数据集AES_T700.xlsx上的测试结果
# TIME： 1.995086669921875
# TPR ： 0.9814814814814815
# TNR ： 1.0
# ACC ： 99.98502321401827
# PRE ： 1.0
# F1  ： 99.52893584087809
# 在数据集AES_T800.xlsx上的测试结果
# TIME： 1.9948482513427734
# TPR ： 0.9940119760479041
# TNR ： 1.0
# ACC ： 99.98540997957397
# PRE ： 1.0
# F1  ： 99.84611153209283
# 在数据集AES_T900.xlsx上的测试结果
# TIME： 1.9943714141845703
# TPR ： 0.9978354978354979
# TNR ： 1.0
# ACC ： 99.98601202965449
# PRE ： 1.0
# F1  ： 99.94209050131124
# 在数据集AES_T1200.xlsx上的测试结果
# TIME： 1.995086669921875
# TPR ： 0.9978354978354979
# TNR ： 1.0
# ACC ： 99.98601202965449
# PRE ： 1.0
# F1  ： 99.94209050131124
# 在数据集AES_T1300.xlsx上的测试结果
# TIME： 1.9943714141845703
# TPR ： 0.9814814814814815
# TNR ： 1.0
# ACC ： 99.98712169993561
# PRE ： 1.0
# F1  ： 99.52946836894286
# 在数据集AES_T1400.xlsx上的测试结果
# TIME： 1.9943714141845703
# TPR ： 0.9939393939393939
# TNR ： 1.0
# ACC ： 99.9918005903575
# PRE ： 1.0
# F1  ： 99.8459464372082
# 在数据集AES_T2000.xlsx上的测试结果
# TIME： 1.9948482513427734
# TPR ： 0.9939393939393939
# TNR ： 1.0
# ACC ： 99.98540572095739
# PRE ： 1.0
# F1  ： 99.84428599835242
# Original samples: 6915
# New samples: 11925
# 5941
# 在数据集AES_T400.xlsx上的测试结果
# TIME： 0.9973049163818359
# TPR ： 0.9871794871794872
# TNR ： 1.0
# ACC ： 99.98507685420086
# PRE ： 1.0
# F1  ： 99.67364491534298
# 在数据集AES_T700.xlsx上的测试结果
# TIME： 1.9915103912353516
# TPR ： 0.9814814814814815
# TNR ： 1.0
# ACC ： 99.98502321401827
# PRE ： 1.0
# F1  ： 99.52893584087809
# 在数据集AES_T800.xlsx上的测试结果
# TIME： 1.9943714141845703
# TPR ： 0.9940119760479041
# TNR ： 1.0
# ACC ： 99.98540997957397
# PRE ： 1.0
# F1  ： 99.84611153209283
# 在数据集AES_T900.xlsx上的测试结果
# TIME： 1.9671916961669922
# TPR ： 0.9978354978354979
# TNR ： 1.0
# ACC ： 99.98601202965449
# PRE ： 1.0
# F1  ： 99.94209050131124
# 在数据集AES_T1200.xlsx上的测试结果
# TIME： 2.00653076171875
# TPR ： 0.9978354978354979
# TNR ： 1.0
# ACC ： 99.98601202965449
# PRE ： 1.0
# F1  ： 99.94209050131124
# 在数据集AES_T1300.xlsx上的测试结果
# TIME： 1.9948482513427734
# TPR ： 0.9814814814814815
# TNR ： 1.0
# ACC ： 99.98712169993561
# PRE ： 1.0
# F1  ： 99.52946836894286
# 在数据集AES_T1400.xlsx上的测试结果
# TIME： 3.0226707458496094
# TPR ： 0.9939393939393939
# TNR ： 1.0
# ACC ： 99.9918005903575
# PRE ： 1.0
# F1  ： 99.8459464372082
# 在数据集AES_T2000.xlsx上的测试结果
# TIME： 1.9953250885009766
# TPR ： 0.9939393939393939
# TNR ： 1.0
# ACC ： 99.98540572095739
# PRE ： 1.0
# F1  ： 99.84428599835242
# Original samples: 6915
# New samples: 11916
# 5932
# 在数据集AES_T400.xlsx上的测试结果
# TIME： 1.9946098327636719
# TPR ： 0.9871794871794872
# TNR ： 1.0
# ACC ： 99.98507685420086
# PRE ： 1.0
# F1  ： 99.67364491534298
# 在数据集AES_T700.xlsx上的测试结果
# TIME： 0.9973049163818359
# TPR ： 0.9814814814814815
# TNR ： 1.0
# ACC ： 99.98502321401827
# PRE ： 1.0
# F1  ： 99.52893584087809
# 在数据集AES_T800.xlsx上的测试结果
# TIME： 1.995086669921875
# TPR ： 0.9940119760479041
# TNR ： 1.0
# ACC ： 99.98540997957397
# PRE ： 1.0
# F1  ： 99.84611153209283
# 在数据集AES_T900.xlsx上的测试结果
# TIME： 1.9946098327636719
# TPR ： 0.9978354978354979
# TNR ： 1.0
# ACC ： 99.98601202965449
# PRE ： 1.0
# F1  ： 99.94209050131124
# 在数据集AES_T1200.xlsx上的测试结果
# TIME： 1.9946098327636719
# TPR ： 0.9978354978354979
# TNR ： 1.0
# ACC ： 99.98601202965449
# PRE ： 1.0
# F1  ： 99.94209050131124
# 在数据集AES_T1300.xlsx上的测试结果
# TIME： 1.9927024841308594
# TPR ： 0.9814814814814815
# TNR ： 1.0
# ACC ： 99.98712169993561
# PRE ： 1.0
# F1  ： 99.52946836894286
# 在数据集AES_T1400.xlsx上的测试结果
# TIME： 2.991914749145508
# TPR ： 0.9939393939393939
# TNR ： 1.0
# ACC ： 99.9918005903575
# PRE ： 1.0
# F1  ： 99.8459464372082
# 在数据集AES_T2000.xlsx上的测试结果
# TIME： 1.995086669921875
# TPR ： 0.9939393939393939
# TNR ： 1.0
# ACC ： 99.98540572095739
# PRE ： 1.0
# F1  ： 99.84428599835242
# Original samples: 6915
# New samples: 11906
# 5922
# 在数据集AES_T400.xlsx上的测试结果
# TIME： 1.9948482513427734
# TPR ： 0.9871794871794872
# TNR ： 1.0
# ACC ： 99.98507685420086
# PRE ： 1.0
# F1  ： 99.67364491534298
# 在数据集AES_T700.xlsx上的测试结果
# TIME： 1.9946098327636719
# TPR ： 0.9814814814814815
# TNR ： 1.0
# ACC ： 99.98502321401827
# PRE ： 1.0
# F1  ： 99.52893584087809
# 在数据集AES_T800.xlsx上的测试结果
# TIME： 1.9946098327636719
# TPR ： 0.9940119760479041
# TNR ： 1.0
# ACC ： 99.98540997957397
# PRE ： 1.0
# F1  ： 99.84611153209283
# 在数据集AES_T900.xlsx上的测试结果
# TIME： 1.9946098327636719
# TPR ： 0.9978354978354979
# TNR ： 1.0
# ACC ： 99.98601202965449
# PRE ： 1.0
# F1  ： 99.94209050131124
# 在数据集AES_T1200.xlsx上的测试结果
# TIME： 1.9943714141845703
# TPR ： 0.9978354978354979
# TNR ： 1.0
# ACC ： 99.98601202965449
# PRE ： 1.0
# F1  ： 99.94209050131124
# 在数据集AES_T1300.xlsx上的测试结果
# TIME： 1.9943714141845703
# TPR ： 0.9814814814814815
# TNR ： 1.0
# ACC ： 99.98712169993561
# PRE ： 1.0
# F1  ： 99.52946836894286
# 在数据集AES_T1400.xlsx上的测试结果
# TIME： 1.964569091796875
# TPR ： 0.9939393939393939
# TNR ： 1.0
# ACC ： 99.9918005903575
# PRE ： 1.0
# F1  ： 99.8459464372082
# 在数据集AES_T2000.xlsx上的测试结果
# TIME： 0.9970664978027344
# TPR ： 0.9939393939393939
# TNR ： 1.0
# ACC ： 99.98540572095739
# PRE ： 1.0
# F1  ： 99.84428599835242
# Original samples: 6915
# New samples: 11917
# 5933
# 在数据集AES_T400.xlsx上的测试结果
# TIME： 1.9948482513427734
# TPR ： 0.9871794871794872
# TNR ： 1.0
# ACC ： 99.98507685420086
# PRE ： 1.0
# F1  ： 99.67364491534298
# 在数据集AES_T700.xlsx上的测试结果
# TIME： 1.9946098327636719
# TPR ： 0.9814814814814815
# TNR ： 1.0
# ACC ： 99.98502321401827
# PRE ： 1.0
# F1  ： 99.52893584087809
# 在数据集AES_T800.xlsx上的测试结果
# TIME： 1.9946098327636719
# TPR ： 0.9940119760479041
# TNR ： 1.0
# ACC ： 99.98540997957397
# PRE ： 1.0
# F1  ： 99.84611153209283
# 在数据集AES_T900.xlsx上的测试结果
# TIME： 1.9943714141845703
# TPR ： 0.9978354978354979
# TNR ： 1.0
# ACC ： 99.98601202965449
# PRE ： 1.0
# F1  ： 99.94209050131124
# 在数据集AES_T1200.xlsx上的测试结果
# TIME： 1.995086669921875
# TPR ： 0.9978354978354979
# TNR ： 1.0
# ACC ： 99.98601202965449
# PRE ： 1.0
# F1  ： 99.94209050131124
# 在数据集AES_T1300.xlsx上的测试结果
# TIME： 1.9943714141845703
# TPR ： 0.9814814814814815
# TNR ： 1.0
# ACC ： 99.98712169993561
# PRE ： 1.0
# F1  ： 99.52946836894286
# 在数据集AES_T1400.xlsx上的测试结果
# TIME： 1.9948482513427734
# TPR ： 0.9939393939393939
# TNR ： 1.0
# ACC ： 99.9918005903575
# PRE ： 1.0
# F1  ： 99.8459464372082
# 在数据集AES_T2000.xlsx上的测试结果
# TIME： 0.9973049163818359
# TPR ： 0.9939393939393939
# TNR ： 1.0
# ACC ： 99.98540572095739
# PRE ： 1.0
# F1  ： 99.84428599835242
# Original samples: 6915
# New samples: 11906
# 5922
# 在数据集AES_T400.xlsx上的测试结果
# TIME： 1.9943714141845703
# TPR ： 0.9871794871794872
# TNR ： 1.0
# ACC ： 99.98507685420086
# PRE ： 1.0
# F1  ： 99.67364491534298
# 在数据集AES_T700.xlsx上的测试结果
# TIME： 0.9975433349609375
# TPR ： 0.9814814814814815
# TNR ： 1.0
# ACC ： 99.98502321401827
# PRE ： 1.0
# F1  ： 99.52893584087809
# 在数据集AES_T800.xlsx上的测试结果
# TIME： 1.9943714141845703
# TPR ： 0.9940119760479041
# TNR ： 1.0
# ACC ： 99.98540997957397
# PRE ： 1.0
# F1  ： 99.84611153209283
# 在数据集AES_T900.xlsx上的测试结果
# TIME： 0.9970664978027344
# TPR ： 0.9978354978354979
# TNR ： 1.0
# ACC ： 99.98601202965449
# PRE ： 1.0
# F1  ： 99.94209050131124
# 在数据集AES_T1200.xlsx上的测试结果
# TIME： 1.9948482513427734
# TPR ： 0.9978354978354979
# TNR ： 1.0
# ACC ： 99.98601202965449
# PRE ： 1.0
# F1  ： 99.94209050131124
# 在数据集AES_T1300.xlsx上的测试结果
# TIME： 1.9948482513427734
# TPR ： 0.9814814814814815
# TNR ： 1.0
# ACC ： 99.98712169993561
# PRE ： 1.0
# F1  ： 99.52946836894286
# 在数据集AES_T1400.xlsx上的测试结果
# TIME： 2.991914749145508
# TPR ： 0.9939393939393939
# TNR ： 1.0
# ACC ： 99.9918005903575
# PRE ： 1.0
# F1  ： 99.8459464372082
# 在数据集AES_T2000.xlsx上的测试结果
# TIME： 0.9977817535400391
# TPR ： 0.9939393939393939
# TNR ： 1.0
# ACC ： 99.98540572095739
# PRE ： 1.0
# F1  ： 99.84428599835242
# Original samples: 6915
# New samples: 11916
# 5932
# 在数据集AES_T400.xlsx上的测试结果
# TIME： 0.9973049163818359
# TPR ： 0.9871794871794872
# TNR ： 1.0
# ACC ： 99.98507685420086
# PRE ： 1.0
# F1  ： 99.67364491534298
# 在数据集AES_T700.xlsx上的测试结果
# TIME： 2.020597457885742
# TPR ： 0.9814814814814815
# TNR ： 1.0
# ACC ： 99.98502321401827
# PRE ： 1.0
# F1  ： 99.52893584087809
# 在数据集AES_T800.xlsx上的测试结果
# TIME： 1.9948482513427734
# TPR ： 0.9940119760479041
# TNR ： 1.0
# ACC ： 99.98540997957397
# PRE ： 1.0
# F1  ： 99.84611153209283
# 在数据集AES_T900.xlsx上的测试结果
# TIME： 1.9946098327636719
# TPR ： 0.9978354978354979
# TNR ： 1.0
# ACC ： 99.98601202965449
# PRE ： 1.0
# F1  ： 99.94209050131124
# 在数据集AES_T1200.xlsx上的测试结果
# TIME： 1.9943714141845703
# TPR ： 0.9978354978354979
# TNR ： 1.0
# ACC ： 99.98601202965449
# PRE ： 1.0
# F1  ： 99.94209050131124
# 在数据集AES_T1300.xlsx上的测试结果
# TIME： 1.9946098327636719
# TPR ： 0.9814814814814815
# TNR ： 1.0
# ACC ： 99.98712169993561
# PRE ： 1.0
# F1  ： 99.52946836894286
# 在数据集AES_T1400.xlsx上的测试结果
# TIME： 1.995086669921875
# TPR ： 0.9939393939393939
# TNR ： 1.0
# ACC ： 99.9918005903575
# PRE ： 1.0
# F1  ： 99.8459464372082
# 在数据集AES_T2000.xlsx上的测试结果
# TIME： 0.9973049163818359
# TPR ： 0.9939393939393939
# TNR ： 1.0
# ACC ： 99.98540572095739
# PRE ： 1.0
# F1  ： 99.84428599835242
# Original samples: 6915
# New samples: 11911
# 5927
# 在数据集AES_T400.xlsx上的测试结果
# TIME： 1.9943714141845703
# TPR ： 0.9871794871794872
# TNR ： 1.0
# ACC ： 99.98507685420086
# PRE ： 1.0
# F1  ： 99.67364491534298
# 在数据集AES_T700.xlsx上的测试结果
# TIME： 2.0232200622558594
# TPR ： 0.9814814814814815
# TNR ： 1.0
# ACC ： 99.98502321401827
# PRE ： 1.0
# F1  ： 99.52893584087809
# 在数据集AES_T800.xlsx上的测试结果
# TIME： 1.9946098327636719
# TPR ： 0.9940119760479041
# TNR ： 1.0
# ACC ： 99.98540997957397
# PRE ： 1.0
# F1  ： 99.84611153209283
# 在数据集AES_T900.xlsx上的测试结果
# TIME： 2.0227432250976562
# TPR ： 0.9978354978354979
# TNR ： 1.0
# ACC ： 99.98601202965449
# PRE ： 1.0
# F1  ： 99.94209050131124
# 在数据集AES_T1200.xlsx上的测试结果
# TIME： 1.9948482513427734
# TPR ： 0.9978354978354979
# TNR ： 1.0
# ACC ： 99.98601202965449
# PRE ： 1.0
# F1  ： 99.94209050131124
# 在数据集AES_T1300.xlsx上的测试结果
# TIME： 2.0232200622558594
# TPR ： 0.9814814814814815
# TNR ： 1.0
# ACC ： 99.98712169993561
# PRE ： 1.0
# F1  ： 99.52946836894286
# 在数据集AES_T1400.xlsx上的测试结果
# TIME： 2.991914749145508
# TPR ： 0.9939393939393939
# TNR ： 1.0
# ACC ： 99.9918005903575
# PRE ： 1.0
# F1  ： 99.8459464372082
# 在数据集AES_T2000.xlsx上的测试结果
# TIME： 1.9943714141845703
# TPR ： 0.9939393939393939
# TNR ： 1.0
# ACC ： 99.98540572095739
# PRE ： 1.0
# F1  ： 99.84428599835242
# Original samples: 6915
# New samples: 11910
# 5926
# 在数据集AES_T400.xlsx上的测试结果
# TIME： 1.993417739868164
# TPR ： 0.9871794871794872
# TNR ： 1.0
# ACC ： 99.98507685420086
# PRE ： 1.0
# F1  ： 99.67364491534298
# 在数据集AES_T700.xlsx上的测试结果
# TIME： 1.9946098327636719
# TPR ： 0.9814814814814815
# TNR ： 1.0
# ACC ： 99.98502321401827
# PRE ： 1.0
# F1  ： 99.52893584087809
# 在数据集AES_T800.xlsx上的测试结果
# TIME： 1.9936561584472656
# TPR ： 0.9940119760479041
# TNR ： 1.0
# ACC ： 99.98540997957397
# PRE ： 1.0
# F1  ： 99.84611153209283
# 在数据集AES_T900.xlsx上的测试结果
# TIME： 1.9946098327636719
# TPR ： 0.9978354978354979
# TNR ： 1.0
# ACC ： 99.98601202965449
# PRE ： 1.0
# F1  ： 99.94209050131124
# 在数据集AES_T1200.xlsx上的测试结果
# TIME： 0.9973049163818359
# TPR ： 0.9978354978354979
# TNR ： 1.0
# ACC ： 99.98601202965449
# PRE ： 1.0
# F1  ： 99.94209050131124
# 在数据集AES_T1300.xlsx上的测试结果
# TIME： 1.9946098327636719
# TPR ： 0.9814814814814815
# TNR ： 1.0
# ACC ： 99.98712169993561
# PRE ： 1.0
# F1  ： 99.52946836894286
# 在数据集AES_T1400.xlsx上的测试结果
# TIME： 3.9894580841064453
# TPR ： 0.9939393939393939
# TNR ： 1.0
# ACC ： 99.9918005903575
# PRE ： 1.0
# F1  ： 99.8459464372082
# 在数据集AES_T2000.xlsx上的测试结果
# TIME： 1.9948482513427734
# TPR ： 0.9939393939393939
# TNR ： 1.0
# ACC ： 99.98540572095739
# PRE ： 1.0
# F1  ： 99.84428599835242
# Original samples: 6915
# New samples: 11921
# 5937
# 在数据集AES_T400.xlsx上的测试结果
# TIME： 1.966714859008789
# TPR ： 0.9871794871794872
# TNR ： 1.0
# ACC ： 99.98507685420086
# PRE ： 1.0
# F1  ： 99.67364491534298
# 在数据集AES_T700.xlsx上的测试结果
# TIME： 1.9941329956054688
# TPR ： 0.9814814814814815
# TNR ： 1.0
# ACC ： 99.98502321401827
# PRE ： 1.0
# F1  ： 99.52893584087809
# 在数据集AES_T800.xlsx上的测试结果
# TIME： 1.9946098327636719
# TPR ： 0.9940119760479041
# TNR ： 1.0
# ACC ： 99.98540997957397
# PRE ： 1.0
# F1  ： 99.84611153209283
# 在数据集AES_T900.xlsx上的测试结果
# TIME： 1.9943714141845703
# TPR ： 0.9978354978354979
# TNR ： 1.0
# ACC ： 99.98601202965449
# PRE ： 1.0
# F1  ： 99.94209050131124
# 在数据集AES_T1200.xlsx上的测试结果
# TIME： 1.9943714141845703
# TPR ： 0.9978354978354979
# TNR ： 1.0
# ACC ： 99.98601202965449
# PRE ： 1.0
# F1  ： 99.94209050131124
# 在数据集AES_T1300.xlsx上的测试结果
# TIME： 1.9943714141845703
# TPR ： 0.9814814814814815
# TNR ： 1.0
# ACC ： 99.98712169993561
# PRE ： 1.0
# F1  ： 99.52946836894286
# 在数据集AES_T1400.xlsx上的测试结果
# TIME： 2.9642581939697266
# TPR ： 0.9939393939393939
# TNR ： 1.0
# ACC ： 99.9918005903575
# PRE ： 1.0
# F1  ： 99.8459464372082
# 在数据集AES_T2000.xlsx上的测试结果
# TIME： 1.9953250885009766
# TPR ： 0.9939393939393939
# TNR ： 1.0
# ACC ： 99.98540572095739
# PRE ： 1.0
# F1  ： 99.84428599835242
# Original samples: 6915
# New samples: 11910
# 5926
# 在数据集AES_T400.xlsx上的测试结果
# TIME： 0.9970664978027344
# TPR ： 0.9871794871794872
# TNR ： 1.0
# ACC ： 99.98507685420086
# PRE ： 1.0
# F1  ： 99.67364491534298
# 在数据集AES_T700.xlsx上的测试结果
# TIME： 1.9941329956054688
# TPR ： 0.9814814814814815
# TNR ： 1.0
# ACC ： 99.98502321401827
# PRE ： 1.0
# F1  ： 99.52893584087809
# 在数据集AES_T800.xlsx上的测试结果
# TIME： 1.9907951354980469
# TPR ： 0.9940119760479041
# TNR ： 1.0
# ACC ： 99.98540997957397
# PRE ： 1.0
# F1  ： 99.84611153209283
# 在数据集AES_T900.xlsx上的测试结果
# TIME： 1.9946098327636719
# TPR ： 0.9978354978354979
# TNR ： 1.0
# ACC ： 99.98601202965449
# PRE ： 1.0
# F1  ： 99.94209050131124
# 在数据集AES_T1200.xlsx上的测试结果
# TIME： 1.9943714141845703
# TPR ： 0.9978354978354979
# TNR ： 1.0
# ACC ： 99.98601202965449
# PRE ： 1.0
# F1  ： 99.94209050131124
# 在数据集AES_T1300.xlsx上的测试结果
# TIME： 1.9915103912353516
# TPR ： 0.9814814814814815
# TNR ： 1.0
# ACC ： 99.98712169993561
# PRE ： 1.0
# F1  ： 99.52946836894286
# 在数据集AES_T1400.xlsx上的测试结果
# TIME： 2.991914749145508
# TPR ： 0.9939393939393939
# TNR ： 1.0
# ACC ： 99.9918005903575
# PRE ： 1.0
# F1  ： 99.8459464372082
# 在数据集AES_T2000.xlsx上的测试结果
# TIME： 1.9941329956054688
# TPR ： 0.9939393939393939
# TNR ： 1.0
# ACC ： 99.98540572095739
# PRE ： 1.0
# F1  ： 99.84428599835242
# Original samples: 6915
# New samples: 11910
# 5926
# 在数据集AES_T400.xlsx上的测试结果
# TIME： 1.9948482513427734
# TPR ： 0.9871794871794872
# TNR ： 1.0
# ACC ： 99.98507685420086
# PRE ： 1.0
# F1  ： 99.67364491534298
# 在数据集AES_T700.xlsx上的测试结果
# TIME： 1.9943714141845703
# TPR ： 0.9814814814814815
# TNR ： 1.0
# ACC ： 99.98502321401827
# PRE ： 1.0
# F1  ： 99.52893584087809
# 在数据集AES_T800.xlsx上的测试结果
# TIME： 1.995086669921875
# TPR ： 0.9940119760479041
# TNR ： 1.0
# ACC ： 99.98540997957397
# PRE ： 1.0
# F1  ： 99.84611153209283
# 在数据集AES_T900.xlsx上的测试结果
# TIME： 1.9953250885009766
# TPR ： 0.9978354978354979
# TNR ： 1.0
# ACC ： 99.98601202965449
# PRE ： 1.0
# F1  ： 99.94209050131124
# 在数据集AES_T1200.xlsx上的测试结果
# TIME： 1.9946098327636719
# TPR ： 0.9978354978354979
# TNR ： 1.0
# ACC ： 99.98601202965449
# PRE ： 1.0
# F1  ： 99.94209050131124
# 在数据集AES_T1300.xlsx上的测试结果
# TIME： 1.992940902709961
# TPR ： 0.9814814814814815
# TNR ： 1.0
# ACC ： 99.98712169993561
# PRE ： 1.0
# F1  ： 99.52946836894286
# 在数据集AES_T1400.xlsx上的测试结果
# TIME： 1.9996166229248047
# TPR ： 0.9939393939393939
# TNR ： 1.0
# ACC ： 99.9918005903575
# PRE ： 1.0
# F1  ： 99.8459464372082
# 在数据集AES_T2000.xlsx上的测试结果
# TIME： 1.9943714141845703
# TPR ： 0.9939393939393939
# TNR ： 1.0
# ACC ： 99.98540572095739
# PRE ： 1.0
# F1  ： 99.84428599835242
# Original samples: 6915
# New samples: 11915
# 5931
# 在数据集AES_T400.xlsx上的测试结果
# TIME： 1.9948482513427734
# TPR ： 0.9871794871794872
# TNR ： 1.0
# ACC ： 99.98507685420086
# PRE ： 1.0
# F1  ： 99.67364491534298
# 在数据集AES_T700.xlsx上的测试结果
# TIME： 1.9946098327636719
# TPR ： 0.9814814814814815
# TNR ： 1.0
# ACC ： 99.98502321401827
# PRE ： 1.0
# F1  ： 99.52893584087809
# 在数据集AES_T800.xlsx上的测试结果
# TIME： 1.9946098327636719
# TPR ： 0.9940119760479041
# TNR ： 1.0
# ACC ： 99.98540997957397
# PRE ： 1.0
# F1  ： 99.84611153209283
# 在数据集AES_T900.xlsx上的测试结果
# TIME： 0.9970664978027344
# TPR ： 0.9978354978354979
# TNR ： 1.0
# ACC ： 99.98601202965449
# PRE ： 1.0
# F1  ： 99.94209050131124
# 在数据集AES_T1200.xlsx上的测试结果
# TIME： 2.0253658294677734
# TPR ： 0.9978354978354979
# TNR ： 1.0
# ACC ： 99.98601202965449
# PRE ： 1.0
# F1  ： 99.94209050131124
# 在数据集AES_T1300.xlsx上的测试结果
# TIME： 1.9943714141845703
# TPR ： 0.9814814814814815
# TNR ： 1.0
# ACC ： 99.98712169993561
# PRE ： 1.0
# F1  ： 99.52946836894286
# 在数据集AES_T1400.xlsx上的测试结果
# TIME： 2.991914749145508
# TPR ： 0.9939393939393939
# TNR ： 1.0
# ACC ： 99.9918005903575
# PRE ： 1.0
# F1  ： 99.8459464372082
# 在数据集AES_T2000.xlsx上的测试结果
# TIME： 1.9946098327636719
# TPR ： 0.9939393939393939
# TNR ： 1.0
# ACC ： 99.98540572095739
# PRE ： 1.0
# F1  ： 99.84428599835242
# Original samples: 6915
# New samples: 11910
# 5926
# 在数据集AES_T400.xlsx上的测试结果
# TIME： 1.9946098327636719
# TPR ： 0.9871794871794872
# TNR ： 1.0
# ACC ： 99.98507685420086
# PRE ： 1.0
# F1  ： 99.67364491534298
# 在数据集AES_T700.xlsx上的测试结果
# TIME： 0.9977817535400391
# TPR ： 0.9814814814814815
# TNR ： 1.0
# ACC ： 99.98502321401827
# PRE ： 1.0
# F1  ： 99.52893584087809
# 在数据集AES_T800.xlsx上的测试结果
# TIME： 1.9946098327636719
# TPR ： 0.9940119760479041
# TNR ： 1.0
# ACC ： 99.98540997957397
# PRE ： 1.0
# F1  ： 99.84611153209283
# 在数据集AES_T900.xlsx上的测试结果
# TIME： 1.9750595092773438
# TPR ： 0.9978354978354979
# TNR ： 1.0
# ACC ： 99.98601202965449
# PRE ： 1.0
# F1  ： 99.94209050131124
# 在数据集AES_T1200.xlsx上的测试结果
# TIME： 0.9968280792236328
# TPR ： 0.9978354978354979
# TNR ： 1.0
# ACC ： 99.98601202965449
# PRE ： 1.0
# F1  ： 99.94209050131124
# 在数据集AES_T1300.xlsx上的测试结果
# TIME： 1.9943714141845703
# TPR ： 0.9814814814814815
# TNR ： 1.0
# ACC ： 99.98712169993561
# PRE ： 1.0
# F1  ： 99.52946836894286
# 在数据集AES_T1400.xlsx上的测试结果
# TIME： 2.9642581939697266
# TPR ： 0.9939393939393939
# TNR ： 1.0
# ACC ： 99.9918005903575
# PRE ： 1.0
# F1  ： 99.8459464372082
# 在数据集AES_T2000.xlsx上的测试结果
# TIME： 0.9973049163818359
# TPR ： 0.9939393939393939
# TNR ： 1.0
# ACC ： 99.98540572095739
# PRE ： 1.0
# F1  ： 99.84428599835242
# Original samples: 6915
# New samples: 11918
# 5934
# 在数据集AES_T400.xlsx上的测试结果
# TIME： 0.9977817535400391
# TPR ： 0.9871794871794872
# TNR ： 1.0
# ACC ： 99.98507685420086
# PRE ： 1.0
# F1  ： 99.67364491534298
# 在数据集AES_T700.xlsx上的测试结果
# TIME： 1.0313987731933594
# TPR ： 0.9814814814814815
# TNR ： 1.0
# ACC ： 99.98502321401827
# PRE ： 1.0
# F1  ： 99.52893584087809
# 在数据集AES_T800.xlsx上的测试结果
# TIME： 1.9941329956054688
# TPR ： 0.9940119760479041
# TNR ： 1.0
# ACC ： 99.98540997957397
# PRE ： 1.0
# F1  ： 99.84611153209283
# 在数据集AES_T900.xlsx上的测试结果
# TIME： 1.9938945770263672
# TPR ： 0.9978354978354979
# TNR ： 1.0
# ACC ： 99.98601202965449
# PRE ： 1.0
# F1  ： 99.94209050131124
# 在数据集AES_T1200.xlsx上的测试结果
# TIME： 1.9948482513427734
# TPR ： 0.9978354978354979
# TNR ： 1.0
# ACC ： 99.98601202965449
# PRE ： 1.0
# F1  ： 99.94209050131124
# 在数据集AES_T1300.xlsx上的测试结果
# TIME： 1.9953250885009766
# TPR ： 0.9814814814814815
# TNR ： 1.0
# ACC ： 99.98712169993561
# PRE ： 1.0
# F1  ： 99.52946836894286
# 在数据集AES_T1400.xlsx上的测试结果
# TIME： 2.991914749145508
# TPR ： 0.9939393939393939
# TNR ： 1.0
# ACC ： 99.9918005903575
# PRE ： 1.0
# F1  ： 99.8459464372082
# 在数据集AES_T2000.xlsx上的测试结果
# TIME： 1.995086669921875
# TPR ： 0.9939393939393939
# TNR ： 1.0
# ACC ： 99.98540572095739
# PRE ： 1.0
# F1  ： 99.84428599835242
# Original samples: 6915
# New samples: 11919
# 5935
# 在数据集AES_T400.xlsx上的测试结果
# TIME： 1.9886493682861328
# TPR ： 0.9871794871794872
# TNR ： 1.0
# ACC ： 99.98507685420086
# PRE ： 1.0
# F1  ： 99.67364491534298
# 在数据集AES_T700.xlsx上的测试结果
# TIME： 1.9946098327636719
# TPR ： 0.9814814814814815
# TNR ： 1.0
# ACC ： 99.98502321401827
# PRE ： 1.0
# F1  ： 99.52893584087809
# 在数据集AES_T800.xlsx上的测试结果
# TIME： 1.0256767272949219
# TPR ： 0.9940119760479041
# TNR ： 1.0
# ACC ： 99.98540997957397
# PRE ： 1.0
# F1  ： 99.84611153209283
# 在数据集AES_T900.xlsx上的测试结果
# TIME： 2.9942989349365234
# TPR ： 0.9978354978354979
# TNR ： 1.0
# ACC ： 99.98601202965449
# PRE ： 1.0
# F1  ： 99.94209050131124
# 在数据集AES_T1200.xlsx上的测试结果
# TIME： 1.9948482513427734
# TPR ： 0.9978354978354979
# TNR ： 1.0
# ACC ： 99.98601202965449
# PRE ： 1.0
# F1  ： 99.94209050131124
# 在数据集AES_T1300.xlsx上的测试结果
# TIME： 1.9674301147460938
# TPR ： 0.9814814814814815
# TNR ： 1.0
# ACC ： 99.98712169993561
# PRE ： 1.0
# F1  ： 99.52946836894286
# 在数据集AES_T1400.xlsx上的测试结果
# TIME： 1.9946098327636719
# TPR ： 0.9939393939393939
# TNR ： 1.0
# ACC ： 99.9918005903575
# PRE ： 1.0
# F1  ： 99.8459464372082
# 在数据集AES_T2000.xlsx上的测试结果
# TIME： 1.9943714141845703
# TPR ： 0.9939393939393939
# TNR ： 1.0
# ACC ： 99.98540572095739
# PRE ： 1.0
# F1  ： 99.84428599835242
# Original samples: 6915
# New samples: 11929
# 5945
# 在数据集AES_T400.xlsx上的测试结果
# TIME： 0.9977817535400391
# TPR ： 0.9871794871794872
# TNR ： 1.0
# ACC ： 99.98507685420086
# PRE ： 1.0
# F1  ： 99.67364491534298
# 在数据集AES_T700.xlsx上的测试结果
# TIME： 1.9936561584472656
# TPR ： 0.9814814814814815
# TNR ： 1.0
# ACC ： 99.98502321401827
# PRE ： 1.0
# F1  ： 99.52893584087809
# 在数据集AES_T800.xlsx上的测试结果
# TIME： 1.9943714141845703
# TPR ： 0.9940119760479041
# TNR ： 1.0
# ACC ： 99.98540997957397
# PRE ： 1.0
# F1  ： 99.84611153209283
# 在数据集AES_T900.xlsx上的测试结果
# TIME： 1.995086669921875
# TPR ： 0.9978354978354979
# TNR ： 1.0
# ACC ： 99.98601202965449
# PRE ： 1.0
# F1  ： 99.94209050131124
# 在数据集AES_T1200.xlsx上的测试结果
# TIME： 1.9943714141845703
# TPR ： 0.9978354978354979
# TNR ： 1.0
# ACC ： 99.98601202965449
# PRE ： 1.0
# F1  ： 99.94209050131124
# 在数据集AES_T1300.xlsx上的测试结果
# TIME： 1.9943714141845703
# TPR ： 0.9814814814814815
# TNR ： 1.0
# ACC ： 99.98712169993561
# PRE ： 1.0
# F1  ： 99.52946836894286
# 在数据集AES_T1400.xlsx上的测试结果
# TIME： 1.995086669921875
# TPR ： 0.9939393939393939
# TNR ： 1.0
# ACC ： 99.9918005903575
# PRE ： 1.0
# F1  ： 99.8459464372082
# 在数据集AES_T2000.xlsx上的测试结果
# TIME： 1.9946098327636719
# TPR ： 0.9939393939393939
# TNR ： 1.0
# ACC ： 99.98540572095739
# PRE ： 1.0
# F1  ： 99.84428599835242
# Original samples: 6915
# New samples: 11923
# 5939
# 在数据集AES_T400.xlsx上的测试结果
# TIME： 1.995086669921875
# TPR ： 0.9871794871794872
# TNR ： 1.0
# ACC ： 99.98507685420086
# PRE ： 1.0
# F1  ： 99.67364491534298
# 在数据集AES_T700.xlsx上的测试结果
# TIME： 0.9973049163818359
# TPR ： 0.9814814814814815
# TNR ： 1.0
# ACC ： 99.98502321401827
# PRE ： 1.0
# F1  ： 99.52893584087809
# 在数据集AES_T800.xlsx上的测试结果
# TIME： 1.995086669921875
# TPR ： 0.9940119760479041
# TNR ： 1.0
# ACC ： 99.98540997957397
# PRE ： 1.0
# F1  ： 99.84611153209283
# 在数据集AES_T900.xlsx上的测试结果
# TIME： 1.0039806365966797
# TPR ： 0.9978354978354979
# TNR ： 1.0
# ACC ： 99.98601202965449
# PRE ： 1.0
# F1  ： 99.94209050131124
# 在数据集AES_T1200.xlsx上的测试结果
# TIME： 2.001047134399414
# TPR ： 0.9978354978354979
# TNR ： 1.0
# ACC ： 99.98601202965449
# PRE ： 1.0
# F1  ： 99.94209050131124
# 在数据集AES_T1300.xlsx上的测试结果
# TIME： 1.9938945770263672
# TPR ： 0.9814814814814815
# TNR ： 1.0
# ACC ： 99.98712169993561
# PRE ： 1.0
# F1  ： 99.52946836894286
# 在数据集AES_T1400.xlsx上的测试结果
# TIME： 2.990245819091797
# TPR ： 0.9939393939393939
# TNR ： 1.0
# ACC ： 99.9918005903575
# PRE ： 1.0
# F1  ： 99.8459464372082
# 在数据集AES_T2000.xlsx上的测试结果
# TIME： 1.9943714141845703
# TPR ： 0.9939393939393939
# TNR ： 1.0
# ACC ： 99.98540572095739
# PRE ： 1.0
# F1  ： 99.84428599835242

# %%
    print("TIME + TPR + TNR + ACC + PRE + F1")
# Out:
# TIME + TPR + TNR + ACC + PRE + F1

# %%
    print(np.mean(p1,axis = 0))
# Out:
# [ 1.59391403  0.98717949  1.         99.98507685  1.         99.67364492]

# %%
    print(np.mean(p2,axis = 0))
# Out:
# [ 1.71776772  0.98148148  1.         99.98502321  1.         99.52893584]

# %%
    print(np.mean(p3,axis = 0))
# Out:
# [ 1.81623936  0.99401198  1.         99.98540998  1.         99.84611153]

# %%
    print(np.mean(p4,axis = 0))
# Out:
# [ 1.77405357  0.9978355   1.         99.98601203  1.         99.9420905 ]

# %%
    print(np.mean(p5,axis = 0))
# Out:
# [ 1.91505909  0.9978355   1.         99.98601203  1.         99.9420905 ]

# %%
    print(np.mean(p6,axis = 0))
# Out:
# [ 1.89578056  0.98148148  1.         99.9871217   1.         99.52946837]

# %%
    print(np.mean(p7,axis = 0))
# Out:
# [ 2.75375843  0.99393939  1.         99.99180059  1.         99.84594644]

# %%
    print(np.mean(p8,axis = 0))
# Out:
# [ 1.83609009  0.99393939  1.         99.98540572  1.         99.844286  ]
